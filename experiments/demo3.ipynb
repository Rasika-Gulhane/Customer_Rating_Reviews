# %%
import pandas as pd
from langchain_core.documents import Document

# %%
product_data=pd.read_csv(r"/Users/rasikagulhane/Desktop/Customer_Rating_Reviews/data/modeified_raw_reviews.csv")

data=product_data

product_list = [['Product_ID','Age','Title','Text_Review','Rating','Type','sentiment','sentiment_score','rating_match']]

# %%
for index, row in data.iterrows():
    # Construct an object with 'product_name' and 'review' attributes
    obj = {


            'product_id': row['Product_ID'],
            'age': row['Age'],
            'review_title': row['Title'],
            'review':row['Text_Review'],
            'ratings':row['Rating'],
            'product_type': row['Type'],
            'sentiment': row['sentiment'],
            'sentiment_score': row['sentiment_score'],
            'rating_match': row['rating_match']
        
            
        }
    # Append the object to the list
    product_list.append(obj)

# %%
product_list
# Out:
# [['Product_ID',
#   'Age',
#   'Title',
#   'Text_Review',
#   'Rating',
#   'Type',
#   'sentiment',
#   'sentiment_score',
#   'rating_match'],
#  {'product_id': 767,
#   'age': 33,
#   'review_title': 'unknown',
#   'review': 'Absolutely wonderful - silky and sexy and comfortable',
#   'ratings': 4,
#   'product_type': 'Intimate',
#   'sentiment': "{'neg': 0.0, 'neu': 0.154, 'pos': 0.846, 'compound': 0.8991}",
#   'sentiment_score': 0.8991,
#   'rating_match': 'Correct'},
#  {'product_id': 1080,
#   'age': 34,
#   'review_title': 'unknown',
#   'review': 'Love this dress!  it\'s sooo pretty.  i happened to find it in a store, and i\'m glad i did bc i never would have ordered it online bc it\'s petite.  i bought a petite and am 5\'8".  i love the length on me- hits just a little below the knee.  would definitely be a true midi on someone who is truly petite.',
#   'ratings': 5,
#   'product_type': 'Dresses',
#   'sentiment': "{'neg': 0.0, 'neu': 0.514, 'pos': 0.486, 'compound': 0.971}",
#   'sentiment_score': 0.971,
#   'rating_match': 'Correct'},
#  {'product_id': 1077,
#   'age': 60,
#   'review_title': 'Some major design flaws',
#   'review': 'I had such high hopes for this dress and really wanted it to work for me. i initially ordered the petite small (my usual size) but i found this to be outrageously small. so small in fact that i could not zip it up! i reordered it in petite medium, which was just ok. overall, the top half was comfortable and fit nicely, but the bottom half had a very tight under layer and several somewhat cheap (net) over layers. imo, a major design flaw was the net over layer sewn directly into the zipper - it c',
#   'ratings': 3,
#   'product_type': 'Dresses',
#   'sentiment': "{'neg': 0.038, 'neu': 0.693, 'pos': 0.269, 'compound': 0.9062}",
#   'sentiment_score': 0.9062,
#   'rating_match': 'Incorrect'},
#  {'product_id': 1049,
#   'age': 50,
#   'review_title': 'My favorite buy!',
#   'review': "I love, love, love this jumpsuit. it's fun, flirty, and fabulous! every time i wear it, i get nothing but great compliments!",
#   'ratings': 5,
#   'product_type': 'Bottoms',
#   'sentiment': "{'neg': 0.171, 'neu': 0.185, 'pos': 0.644, 'compound': 0.9464}",
#   'sentiment_score': 0.9464,
#   'rating_match': 'Correct'},
#  {'product_id': 847,
#   'age': 47,
#   'review_title': 'Flattering shirt',
#   'review': 'This shirt is very flattering to all due to the adjustable front tie. it is the perfect length to wear with leggings and it is sleeveless so it pairs well with any cardigan. love this shirt!!!',
#   'ratings': 5,
#   'product_type': 'Tops',
#   'sentiment': "{'neg': 0.0, 'neu': 0.494, 'pos': 0.506, 'compound': 0.9062}",
#   'sentiment_score': 0.9062,
#   'rating_match': 'Correct'},
#  {'product_id': 1080,
#   'age': 49,
#   'review_title': 'Not for the very petite',
#   'review': 'I love tracy reese dresses, but this one is not for the very petite. i am just under 5 feet tall and usually wear a 0p in this brand. this dress was very pretty out of the package but its a lot of dress. the skirt is long and very full so it overwhelmed my small frame. not a stranger to alterations, shortening and narrowing the skirt would take away from the embellishment of the garment. i love the color and the idea of the style but it just did not work on me. i returned this dress.',
#   'ratings': 2,
#   'product_type': 'Dresses',
#   'sentiment': "{'neg': 0.0, 'neu': 0.738, 'pos': 0.262, 'compound': 0.9153}",
#   'sentiment_score': 0.9153,
#   'rating_match': 'Incorrect'},
#  {'product_id': 858,
#   'age': 39,
#   'review_title': 'Cagrcoal shimmer fun',
#   'review': 'I aded this in my basket at hte last mintue to see what it would look like in person. (store pick up). i went with teh darkler color only because i am so pale :-) hte color is really gorgeous, and turns out it mathced everythiing i was trying on with it prefectly. it is a little baggy on me and hte xs is hte msallet size (bummer, no petite). i decided to jkeep it though, because as i said, it matvehd everything. my ejans, pants, and the 3 skirts i waas trying on (of which i ]kept all ) oops.',
#   'ratings': 5,
#   'product_type': 'Tops',
#   'sentiment': "{'neg': 0.048, 'neu': 0.827, 'pos': 0.125, 'compound': 0.6361}",
#   'sentiment_score': 0.6361,
#   'rating_match': 'Correct'},
#  {'product_id': 858,
#   'age': 39,
#   'review_title': 'Shimmer, surprisingly goes with lots',
#   'review': "I ordered this in carbon for store pick up, and had a ton of stuff (as always) to try on and used this top to pair (skirts and pants). everything went with it. the color is really nice charcoal with shimmer, and went well with pencil skirts, flare pants, etc. my only compaint is it is a bit big, sleeves are long and it doesn't go in petite. also a bit loose for me, but no xxs... so i kept it and wil ldecide later since the light color is already sold out in hte smallest size...",
#   'ratings': 4,
#   'product_type': 'Tops',
#   'sentiment': "{'neg': 0.041, 'neu': 0.835, 'pos': 0.124, 'compound': 0.5709}",
#   'sentiment_score': 0.5709,
#   'rating_match': 'Correct'},
#  {'product_id': 1077,
#   'age': 24,
#   'review_title': 'Flattering',
#   'review': 'I love this dress. i usually get an xs but it runs a little snug in bust so i ordered up a size. very flattering and feminine with the usual retailer flair for style.',
#   'ratings': 5,
#   'product_type': 'Dresses',
#   'sentiment': "{'neg': 0.0, 'neu': 0.698, 'pos': 0.302, 'compound': 0.7579}",
#   'sentiment_score': 0.7579,
#   'rating_match': 'Correct'},
#  {'product_id': 1077,
#   'age': 34,
#   'review_title': 'Such a fun dress!',
#   'review': 'I\'m 5"5\' and 125 lbs. i ordered the s petite to make sure the length wasn\'t too long. i typically wear an xs regular in retailer dresses. if you\'re less busty (34b cup or smaller), a s petite will fit you perfectly (snug, but not tight). i love that i could dress it up for a party, or down for work. i love that the tulle is longer then the fabric underneath.',
#   'ratings': 5,
#   'product_type': 'Dresses',
#   'sentiment': "{'neg': 0.0, 'neu': 0.614, 'pos': 0.386, 'compound': 0.9643}",
#   'sentiment_score': 0.9643,
#   'rating_match': 'Correct'},
#  {'product_id': 1077,
#   'age': 53,
#   'review_title': "Dress looks like it's made of cheap material",
#   'review': 'Dress runs small esp where the zipper area runs. i ordered the sp which typically fits me and it was very tight! the material on the top looks and feels very cheap that even just pulling on it will cause it to rip the fabric. pretty disappointed as it was going to be my christmas dress this year! needless to say it will be going back.',
#   'ratings': 3,
#   'product_type': 'Dresses',
#   'sentiment': "{'neg': 0.084, 'neu': 0.782, 'pos': 0.135, 'compound': 0.2263}",
#   'sentiment_score': 0.2263,
#   'rating_match': 'Incorrect'},
#  {'product_id': 1095,
#   'age': 39,
#   'review_title': 'unknown',
#   'review': 'This dress is perfection! so pretty and flattering.',
#   'ratings': 5,
#   'product_type': 'Dresses',
#   'sentiment': "{'neg': 0.0, 'neu': 0.098, 'pos': 0.902, 'compound': 0.8481}",
#   'sentiment_score': 0.8481,
#   'rating_match': 'Correct'},
#  {'product_id': 1095,
#   'age': 53,
#   'review_title': 'Perfect!!!',
#   'review': 'More and more i find myself reliant on the reviews written by savvy shoppers before me and for the most past, they are right on in their estimation of the product. in the case of this dress-if it had not been for the reveiws-i doubt i would have even tried this. the dress is beautifully made, lined and reminiscent of the old retailer quality. it is lined in the solid periwinkle-colored fabric that matches the outer fabric print. tts and very form-fitting. falls just above the knee and does not rid',
#   'ratings': 5,
#   'product_type': 'Dresses',
#   'sentiment': "{'neg': 0.058, 'neu': 0.785, 'pos': 0.157, 'compound': 0.5106}",
#   'sentiment_score': 0.5106,
#   'rating_match': 'Correct'},
#  {'product_id': 767,
#   'age': 44,
#   'review_title': 'Runs big',
#   'review': 'Bought the black xs to go under the larkspur midi dress because they didn\'t bother lining the skirt portion (grrrrrrrrrrr).\r\nmy stats are 34a-28/29-36 and the xs fit very smoothly around the chest and was flowy around my lower half, so i would say it\'s running big.\r\nthe straps are very pretty and it could easily be nightwear too.\r\ni\'m 5\'6" and it came to just below my knees.',
#   'ratings': 5,
#   'product_type': 'Intimate',
#   'sentiment': "{'neg': 0.05, 'neu': 0.722, 'pos': 0.229, 'compound': 0.7867}",
#   'sentiment_score': 0.7867,
#   'rating_match': 'Correct'},
#  {'product_id': 1077,
#   'age': 50,
#   'review_title': 'Pretty party dress with some issues',
#   'review': 'This is a nice choice for holiday gatherings. i like that the length grazes the knee so it is conservative enough for office related gatherings. the size small fit me well - i am usually a size 2/4 with a small bust. in my opinion it runs small and those with larger busts will definitely have to size up (but then perhaps the waist will be too big). the problem with this dress is the quality. the fabrics are terrible. the delicate netting type fabric on the top layer of skirt got stuck in the zip',
#   'ratings': 3,
#   'product_type': 'Dresses',
#   'sentiment': "{'neg': 0.126, 'neu': 0.58, 'pos': 0.295, 'compound': 0.8176}",
#   'sentiment_score': 0.8176,
#   'rating_match': 'Incorrect'},
#  {'product_id': 1065,
#   'age': 47,
#   'review_title': 'Nice, but not for my body',
#   'review': "I took these out of the package and wanted them to fit so badly, but i could tell before i put them on that they wouldn't. these are for an hour-glass figure. i am more straight up and down. the waist was way too small for my body shape and even if i sized up, i could tell they would still be tight in the waist and too roomy in the hips - for me. that said, they are really nice. sturdy, linen-like fabric, pretty color, well made. i hope they make someone very happy!",
#   'ratings': 4,
#   'product_type': 'Bottoms',
#   'sentiment': "{'neg': 0.086, 'neu': 0.597, 'pos': 0.317, 'compound': 0.914}",
#   'sentiment_score': 0.914,
#   'rating_match': 'Correct'},
#  {'product_id': 1065,
#   'age': 34,
#   'review_title': 'You need to be at least average height, or taller',
#   'review': "Material and color is nice.  the leg opening is very large.  i am 5'1 (100#) and the length hits me right above my ankle.  with a leg opening the size of my waist and hem line above my ankle, and front pleats to make me fluffy, i think you can imagine that it is not a flattering look.  if you are at least average height or taller, this may look good on you.",
#   'ratings': 3,
#   'product_type': 'Bottoms',
#   'sentiment': "{'neg': 0.0, 'neu': 0.795, 'pos': 0.205, 'compound': 0.7906}",
#   'sentiment_score': 0.7906,
#   'rating_match': 'Incorrect'},
#  {'product_id': 853,
#   'age': 41,
#   'review_title': 'Looks great with white pants',
#   'review': "Took a chance on this blouse and so glad i did. i wasn't crazy about how the blouse is photographed on the model. i paired it whit white pants and it worked perfectly. crisp and clean is how i would describe it. launders well. fits great. drape is perfect. wear tucked in or out - can't go wrong.",
#   'ratings': 5,
#   'product_type': 'Tops',
#   'sentiment': "{'neg': 0.0, 'neu': 0.443, 'pos': 0.557, 'compound': 0.9761}",
#   'sentiment_score': 0.9761,
#   'rating_match': 'Correct'},
#  {'product_id': 1120,
#   'age': 32,
#   'review_title': 'Super cute and cozy',
#   'review': "A flattering, super cozy coat.  will work well for cold, dry days and will look good with jeans or a dressier outfit.  i am 5' 5'', about 135 and the small fits great.",
#   'ratings': 5,
#   'product_type': 'Jackets',
#   'sentiment': "{'neg': 0.0, 'neu': 0.459, 'pos': 0.541, 'compound': 0.936}",
#   'sentiment_score': 0.936,
#   'rating_match': 'Correct'},
#  {'product_id': 1077,
#   'age': 47,
#   'review_title': 'Stylish and comfortable',
#   'review': "I love the look and feel of this tulle dress. i was looking for something different, but not over the top for new year's eve. i'm small chested and the top of this dress is form fitting for a flattering look. once i steamed the tulle, it was perfect! i ordered an xsp. length was perfect too.",
#   'ratings': 5,
#   'product_type': 'Dresses',
#   'sentiment': "{'neg': 0.0, 'neu': 0.557, 'pos': 0.443, 'compound': 0.9477}",
#   'sentiment_score': 0.9477,
#   'rating_match': 'Correct'},
#  {'product_id': 847,
#   'age': 33,
#   'review_title': 'Cute, crisp shirt',
#   'review': "If this product was in petite, i would get the petite. the regular is a little long on me but a tailor can do a simple fix on that. \r\n\r\nfits nicely! i'm 5'4, 130lb and pregnant so i bough t medium to grow into. \r\n\r\nthe tie can be front or back so provides for some nice flexibility on form fitting.",
#   'ratings': 4,
#   'product_type': 'Tops',
#   'sentiment': "{'neg': 0.0, 'neu': 0.755, 'pos': 0.245, 'compound': 0.7964}",
#   'sentiment_score': 0.7964,
#   'rating_match': 'Correct'},
#  {'product_id': 1080,
#   'age': 55,
#   'review_title': "I'm torn!",
#   'review': "I'm upset because for the price of the dress, i thought it was embroidered! no, that is a print on the fabric. i think i cried a little when i opened the box. it is still ver pretty. i would say it is true to size, it is a tad bit big on me, but i am very tiny, but i can still get away with it. the color is vibrant. the style is unique. skirt portion is pretty poofy. i keep going back and forth on it mainly because of the price, although the quality is definitely there. except i wish it were emb",
#   'ratings': 4,
#   'product_type': 'Dresses',
#   'sentiment': "{'neg': 0.084, 'neu': 0.627, 'pos': 0.289, 'compound': 0.9153}",
#   'sentiment_score': 0.9153,
#   'rating_match': 'Correct'},
#  {'product_id': 1077,
#   'age': 31,
#   'review_title': 'Not what it looks like',
#   'review': "First of all, this is not pullover styling. there is a side zipper. i wouldn't have purchased it if i knew there was a side zipper because i have a large bust and side zippers are next to impossible for me.\n\nsecond of all, the tulle feels and looks cheap and the slip has an awkward tight shape underneath.\n\nnot at all what is looks like or is described as. sadly will be returning, but i'm sure i will find something to exchange it for!",
#   'ratings': 2,
#   'product_type': 'Dresses',
#   'sentiment': "{'neg': 0.107, 'neu': 0.777, 'pos': 0.117, 'compound': 0.1027}",
#   'sentiment_score': 0.1027,
#   'rating_match': 'Incorrect'},
#  {'product_id': 1077,
#   'age': 34,
#   'review_title': "Like it, but don't love it.",
#   'review': "Cute little dress fits tts. it is a little high waisted. good length for my 5'9 height. i like the dress, i'm just not in love with it. i dont think it looks or feels cheap. it appears just as pictured.",
#   'ratings': 3,
#   'product_type': 'Dresses',
#   'sentiment': "{'neg': 0.0, 'neu': 0.606, 'pos': 0.394, 'compound': 0.9069}",
#   'sentiment_score': 0.9069,
#   'rating_match': 'Incorrect'},
#  {'product_id': 847,
#   'age': 55,
#   'review_title': 'Versatile',
#   'review': "I love this shirt because when i first saw it, i wasn't sure if it was a shirt or dress. since it is see-through if you wear it like a dress you will need a slip or wear it with leggings. i bought a slip, wore the tie in the back, and rocked it with white wedges. you could also wear it as a vest. be careful with the buttons. i haven't had any fall off yet, but i feel like they will. overall it's great for any occasion and it's fun to wear!",
#   'ratings': 5,
#   'product_type': 'Tops',
#   'sentiment': "{'neg': 0.036, 'neu': 0.628, 'pos': 0.336, 'compound': 0.9454}",
#   'sentiment_score': 0.9454,
#   'rating_match': 'Correct'},
#  {'product_id': 697,
#   'age': 31,
#   'review_title': 'Falls flat',
#   'review': 'Loved the material, but i didnt really look at how long the dress was before i purchased both a large and a medium. im 5\'5" and there was atleast 5" of material at my feet. the gaps in the front are much wider than they look. felt like the dress just fell flat. both were returned. im usually a large and the med fit better. 36d 30 in jeans',
#   'ratings': 3,
#   'product_type': 'Intimate',
#   'sentiment': "{'neg': 0.0, 'neu': 0.724, 'pos': 0.276, 'compound': 0.8957}",
#   'sentiment_score': 0.8957,
#   'rating_match': 'Incorrect'},
#  {'product_id': 949,
#   'age': 33,
#   'review_title': 'Huge disappointment',
#   'review': "I have been waiting for this sweater coat to ship for weeks and i was so excited for it to arrive. this coat is not true to size and made me look short and squat. the sleeves are very wide (although long). as a light weight fall coat the sleeves don't need to be as wide because you wouldn't be layerng too much underneath. the buttons need to be moved at least three inches in for a nicer fit. i thought about redoing the buttons myself but the sleeves looked even more out of proportion with a tigh",
#   'ratings': 2,
#   'product_type': 'Tops',
#   'sentiment': "{'neg': 0.0, 'neu': 0.798, 'pos': 0.202, 'compound': 0.8625}",
#   'sentiment_score': 0.8625,
#   'rating_match': 'Incorrect'},
#  {'product_id': 1003,
#   'age': 31,
#   'review_title': 'Loved, but returned',
#   'review': "The colors weren't what i expected either. the dark blue is much more vibrant and i just couldn't find anything to really go with it. fabric is thick and good quality. has nice weight and movement to it. the skirt just wasn't for me, in the end.",
#   'ratings': 4,
#   'product_type': 'Bottoms',
#   'sentiment': "{'neg': 0.0, 'neu': 0.687, 'pos': 0.313, 'compound': 0.8442}",
#   'sentiment_score': 0.8442,
#   'rating_match': 'Correct'},
#  {'product_id': 684,
#   'age': 53,
#   'review_title': 'Great shirt!!!',
#   'review': "I have several of goodhyouman shirts and i get so many compliments on them. especially the one that says forehead kisses are underrated. don't hesitate. buy this shirt. you won't be sorry.....",
#   'ratings': 5,
#   'product_type': 'Intimate',
#   'sentiment': "{'neg': 0.0, 'neu': 0.608, 'pos': 0.392, 'compound': 0.7927}",
#   'sentiment_score': 0.7927,
#   'rating_match': 'Correct'},
#  {'product_id': 4,
#   'age': 28,
#   'review_title': 'Great layering piece',
#   'review': "This sweater is so comfy and classic - it balances a quirky hand-knit look with a beautiful color and practical fit. it is a bit cropped and boxy as part of the style, and as others mentioned, there are gaps in the knit that make it see-through. in my opinion this makes it perfect for layering! i like having a longer camisole showing underneath, or wearing it over a little dress. it's warm but still thin enough to fit under a jacket or coat.",
#   'ratings': 5,
#   'product_type': 'Tops',
#   'sentiment': "{'neg': 0.0, 'neu': 0.677, 'pos': 0.323, 'compound': 0.9405}",
#   'sentiment_score': 0.9405,
#   'rating_match': 'Correct'},
#  {'product_id': 1060,
#   'age': 33,
#   'review_title': 'unknown',
#   'review': 'Beautifully made pants and on trend with the flared crop. so much cuter in person. love these!',
#   'ratings': 5,
#   'product_type': 'Bottoms',
#   'sentiment': "{'neg': 0.0, 'neu': 0.385, 'pos': 0.615, 'compound': 0.9042}",
#   'sentiment_score': 0.9042,
#   'rating_match': 'Correct'},
#  {'product_id': 1060,
#   'age': 46,
#   'review_title': 'Cuter in oerson!',
#   'review': "I never would have given these pants a second look online, in person they are much cuter! the stripes are brighter and the fit more flattering. the crop has a cute flare which is right on trend. this brand has always run small for me, i am 5'8 about 140lbs and carry some chubbiness in the belly. i paired it with a collarless loose navy blazer",
#   'ratings': 5,
#   'product_type': 'Bottoms',
#   'sentiment': "{'neg': 0.053, 'neu': 0.628, 'pos': 0.319, 'compound': 0.886}",
#   'sentiment_score': 0.886,
#   'rating_match': 'Correct'},
#  {'product_id': 1060,
#   'age': 21,
#   'review_title': 'Love these pants',
#   'review': 'These pants are even better in person. the only downside is that they need to be dry cleaned.',
#   'ratings': 5,
#   'product_type': 'Bottoms',
#   'sentiment': "{'neg': 0.183, 'neu': 0.55, 'pos': 0.266, 'compound': 0.2263}",
#   'sentiment_score': 0.2263,
#   'rating_match': 'Correct'},
#  {'product_id': 949,
#   'age': 36,
#   'review_title': 'Mehh',
#   'review': 'I ordered this 3 months ago, and it finally came off back order. a huge disappointment. the fit wasn&#39;t so much the issue for me. the quality of the wool is subpar. someone else mentioned a &quot;felted wool&quot;...i guess, is that what you call it?  it does literally feel like felt! super thin, itchy, doesn&#39;t drape very well, and feels cheap (made in china). i got it on sale, but still not worth what i paid. definitely going back.',
#   'ratings': 2,
#   'product_type': 'Tops',
#   'sentiment': "{'neg': 0.091, 'neu': 0.607, 'pos': 0.302, 'compound': 0.8885}",
#   'sentiment_score': 0.8885,
#   'rating_match': 'Incorrect'},
#  {'product_id': 697,
#   'age': 39,
#   'review_title': 'Love this dress!',
#   'review': 'This is such a neat dress. the color is great and the fabric is super soft. i am tall so the long length was an added bonus. it definitely needs something underneath since the front gaps. i am going to pair it with a funky tank top, necklaces and boots. super cute!!',
#   'ratings': 5,
#   'product_type': 'Intimate',
#   'sentiment': "{'neg': 0.03, 'neu': 0.41, 'pos': 0.559, 'compound': 0.9764}",
#   'sentiment_score': 0.9764,
#   'rating_match': 'Correct'},
#  {'product_id': 1060,
#   'age': 65,
#   'review_title': 'Lovely!',
#   'review': "Wouldn't have given them a second look but tried them on in store of a whim. love, love!!",
#   'ratings': 4,
#   'product_type': 'Bottoms',
#   'sentiment': "{'neg': 0.0, 'neu': 0.455, 'pos': 0.545, 'compound': 0.8555}",
#   'sentiment_score': 0.8555,
#   'rating_match': 'Correct'},
#  {'product_id': 1002,
#   'age': 29,
#   'review_title': 'unknown',
#   'review': 'This is a comfortable skirt that can span seasons easily. while not the most exciting design, it is a good work skirt that can be paired with many tops.',
#   'ratings': 4,
#   'product_type': 'Bottoms',
#   'sentiment': "{'neg': 0.0, 'neu': 0.346, 'pos': 0.654, 'compound': 0.9337}",
#   'sentiment_score': 0.9337,
#   'rating_match': 'Correct'},
#  {'product_id': 949,
#   'age': 38,
#   'review_title': 'Beautifully cut lightweight coat',
#   'review': 'Just ordered this in a small for me (5\'6", 135, size 4) and medium for my mom (5\'3", 130, size 8) and it is gorgeous - beautifully draped, all the weight/warmth i\'ll need for houston fall and winter, looks polished snapped or unsnapped. age-appropriate for both my mom (60\'s) and myself (30\'s). will look amazing with skinny jeans or leggings. we ordered the gray which is true to the photos.',
#   'ratings': 5,
#   'product_type': 'Tops',
#   'sentiment': "{'neg': 0.058, 'neu': 0.644, 'pos': 0.297, 'compound': 0.91}",
#   'sentiment_score': 0.91,
#   'rating_match': 'Correct'},
#  {'product_id': 684,
#   'age': 36,
#   'review_title': 'unknown',
#   'review': 'Super cute and comfy pull over. sizing is accurate. material has a little bit of stretch.',
#   'ratings': 5,
#   'product_type': 'Intimate',
#   'sentiment': "{'neg': 0.0, 'neu': 0.537, 'pos': 0.463, 'compound': 0.7845}",
#   'sentiment_score': 0.7845,
#   'rating_match': 'Correct'},
#  {'product_id': 862,
#   'age': 59,
#   'review_title': 'unknown',
#   'review': 'Great casual top with flare. looks cute with grey pilcro stet jeans. flattering with peplum in back. nice cut for shoulders and neckline.',
#   'ratings': 5,
#   'product_type': 'Tops',
#   'sentiment': "{'neg': 0.075, 'neu': 0.32, 'pos': 0.605, 'compound': 0.9169}",
#   'sentiment_score': 0.9169,
#   'rating_match': 'Correct'},
#  {'product_id': 862,
#   'age': 47,
#   'review_title': 'unknown',
#   'review': 'Pretty and unique. great with jeans or i have worn it to work with slacks and heels. the colors, print, and embroidery are lovely. reasonably priced!',
#   'ratings': 4,
#   'product_type': 'Tops',
#   'sentiment': "{'neg': 0.094, 'neu': 0.429, 'pos': 0.476, 'compound': 0.872}",
#   'sentiment_score': 0.872,
#   'rating_match': 'Correct'},
#  {'product_id': 862,
#   'age': 40,
#   'review_title': 'unknown',
#   'review': "This is a beautiful top. it's unique and not so ordinary. i bought my usual medium and i found that it fits tight across my chest. although i had a baby this year and i am nursing, so that could be why. if i bought again i would size up.",
#   'ratings': 5,
#   'product_type': 'Tops',
#   'sentiment': "{'neg': 0.0, 'neu': 0.759, 'pos': 0.241, 'compound': 0.6908}",
#   'sentiment_score': 0.6908,
#   'rating_match': 'Correct'},
#  {'product_id': 910,
#   'age': 23,
#   'review_title': 'Soft & lovely',
#   'review': 'This poncho is so cute i love the plaid check design, the colors look like sorbet & cream and it will pair well with a turtleneck and jeans or pencil skirt and heels. i love this look for fall and it can roll right into spring. great buy!!',
#   'ratings': 5,
#   'product_type': 'Tops',
#   'sentiment': "{'neg': 0.0, 'neu': 0.499, 'pos': 0.501, 'compound': 0.9643}",
#   'sentiment_score': 0.9643,
#   'rating_match': 'Correct'},
#  {'product_id': 89,
#   'age': 67,
#   'review_title': 'Some things you should know...',
#   'review': 'First, this is thermal ,so naturally i didn\'t expect super sheer, but it is. really sheer light fabric. i like it, but be prepared for considering who you might run into if you walk around the house in it. second, it is large. i ordered the size 0 and it\'s a nice oversized fit for my 5\'3" 125 pounds. i wouldn\'t want to go larger. along with being sheer, the fabric is easily stretched, which i don\'t mind in this case. finally, the color. it looks white on my monitor and shows a colorful blue dot',
#   'ratings': 4,
#   'product_type': 'Intimate',
#   'sentiment': "{'neg': 0.073, 'neu': 0.723, 'pos': 0.203, 'compound': 0.7738}",
#   'sentiment_score': 0.7738,
#   'rating_match': 'Correct'},
#  {'product_id': 862,
#   'age': 48,
#   'review_title': 'Beautiful!',
#   'review': 'Tried this on today at my local retailer and had to have it. it is so comfortable and flattering. it\'s too bad the picture online has the model tucking it into the skirt because you can\'t see the ruching across the front. a little dressier alternative to a plain tee and reasonably priced for retailer. 5\'8"" and i generally wear a 6, the small fit well. will probably be back for the black!',
#   'ratings': 5,
#   'product_type': 'Tops',
#   'sentiment': "{'neg': 0.082, 'neu': 0.679, 'pos': 0.239, 'compound': 0.6908}",
#   'sentiment_score': 0.6908,
#   'rating_match': 'Correct'},
#  {'product_id': 862,
#   'age': 43,
#   'review_title': 'Love the two tone design',
#   'review': 'I bought this item from online... the fit on the model looked a little loose but when i got mine it seemed a bit tight! so i took it back to the store & ordered a larger size. for the sale price this is a great top.',
#   'ratings': 4,
#   'product_type': 'Tops',
#   'sentiment': "{'neg': 0.068, 'neu': 0.646, 'pos': 0.286, 'compound': 0.7501}",
#   'sentiment_score': 0.7501,
#   'rating_match': 'Correct'},
#  {'product_id': 862,
#   'age': 40,
#   'review_title': 'unknown',
#   'review': "I love this top. i wear it all the time.  the problem is that you can tell i wear it all the time as the fabric has started to fade.  i'd still recommend it as it is so comfortable.",
#   'ratings': 5,
#   'product_type': 'Tops',
#   'sentiment': "{'neg': 0.11, 'neu': 0.408, 'pos': 0.482, 'compound': 0.8442}",
#   'sentiment_score': 0.8442,
#   'rating_match': 'Correct'},
#  {'product_id': 823,
#   'age': 52,
#   'review_title': 'unknown',
#   'review': 'Very comfortable, material is good, cut out on sleeves flattering',
#   'ratings': 5,
#   'product_type': 'Tops',
#   'sentiment': "{'neg': 0.167, 'neu': 0.159, 'pos': 0.675, 'compound': 0.7506}",
#   'sentiment_score': 0.7506,
#   'rating_match': 'Correct'},
#  {'product_id': 910,
#   'age': 56,
#   'review_title': 'Love the color!',
#   'review': "This sweater is perfect for fall...it's roomy, warm, super comfy and the color really pops.",
#   'ratings': 5,
#   'product_type': 'Tops',
#   'sentiment': "{'neg': 0.0, 'neu': 0.424, 'pos': 0.576, 'compound': 0.8591}",
#   'sentiment_score': 0.8591,
#   'rating_match': 'Correct'},
#  {'product_id': 862,
#   'age': 33,
#   'review_title': 'Love the embroidery!',
#   'review': "Really cute top! the embroidery on the collar & bib of this top is beautiful and unique, received lots of compliments & questions about where i got it. i'm rather busty up top and the medium fit well, a small probably would've fit better but it's still super adorable.",
#   'ratings': 5,
#   'product_type': 'Tops',
#   'sentiment': "{'neg': 0.0, 'neu': 0.338, 'pos': 0.662, 'compound': 0.9838}",
#   'sentiment_score': 0.9838,
#   'rating_match': 'Correct'},
#  {'product_id': 862,
#   'age': 46,
#   'review_title': 'Cute for fall',
#   'review': "This is a cute top that can transition easily from summer to fall. it fits well, nice print and it's comfortable. i tried this on in the store, but did not purchase it because the color washed me out. this is not the best color for a blonde. would look much better on a brunette. if this was in a different color i most likely would have purchased it.",
#   'ratings': 4,
#   'product_type': 'Tops',
#   'sentiment': "{'neg': 0.0, 'neu': 0.483, 'pos': 0.517, 'compound': 0.9661}",
#   'sentiment_score': 0.9661,
#   'rating_match': 'Correct'},
#  {'product_id': 862,
#   'age': 41,
#   'review_title': 'Love',
#   'review': 'I absolutely love this bib tee! it\'s probably my favorite retailer purchase of all time. i\'m 5\'7", 140 pounds and the small was a perfect fit for me. i typically wear either a s or m tops.',
#   'ratings': 5,
#   'product_type': 'Tops',
#   'sentiment': "{'neg': 0.0, 'neu': 0.469, 'pos': 0.531, 'compound': 0.9516}",
#   'sentiment_score': 0.9516,
#   'rating_match': 'Correct'},
#  {'product_id': 1104,
#   'age': 39,
#   'review_title': 'unknown',
#   'review': 'Love the color and style, but material snags easily',
#   'ratings': 3,
#   'product_type': 'Dresses',
#   'sentiment': "{'neg': 0.0, 'neu': 0.377, 'pos': 0.623, 'compound': 0.765}",
#   'sentiment_score': 0.765,
#   'rating_match': 'Incorrect'},
#  {'product_id': 862,
#   'age': 39,
#   'review_title': 'Flattering and comfortable',
#   'review': "Very soft and comfortable. the shirt has an unusual, asymmetrical seam that appears along the front, right-hand side of the garment. (the model is positioned so that you can't see this detail from the picture. i attached a picture that includes the front seam.) i actually like the seam - it creates more visual interest, and adds a little bit of ruching that helps hide my belly. the cowl neck is very well done - there are two layers that form the cowl, and i've found that it means wardrobe malfun",
#   'ratings': 5,
#   'product_type': 'Tops',
#   'sentiment': "{'neg': 0.029, 'neu': 0.711, 'pos': 0.26, 'compound': 0.9124}",
#   'sentiment_score': 0.9124,
#   'rating_match': 'Correct'},
#  {'product_id': 862,
#   'age': 66,
#   'review_title': 'Cute top',
#   'review': "Nice top. armholes are a bit oversized but as an older woman, i'm picky about that. the print is pretty and unusual. it just didn't look great on me. there's a slight peplum in the back that hangs nicely. it's a lightweight tee fabric that's opaque. i tried it on with a black bra which was barely visible. great for warmer climates but there are so many gorgeous tops out now, that i decided to return since summer is winding down. i do recommend.",
#   'ratings': 4,
#   'product_type': 'Tops',
#   'sentiment': "{'neg': 0.106, 'neu': 0.532, 'pos': 0.362, 'compound': 0.9306}",
#   'sentiment_score': 0.9306,
#   'rating_match': 'Correct'},
#  {'product_id': 862,
#   'age': 61,
#   'review_title': 'Soft and cute as can be!',
#   'review': "This is an adorable top that i find to be extremely comfortable. i don't usually buy prints but this one is so feminine and looks great with dark wash jeans. i am a 36d and the medium was a perfect fit.",
#   'ratings': 5,
#   'product_type': 'Tops',
#   'sentiment': "{'neg': 0.0, 'neu': 0.426, 'pos': 0.574, 'compound': 0.9577}",
#   'sentiment_score': 0.9577,
#   'rating_match': 'Correct'},
#  {'product_id': 368,
#   'age': 33,
#   'review_title': 'unknown',
#   'review': "I am pregnant and i thought this would be a great sleep bra. it's soft and fits okay, but it has zero support or shape. i would only buy if you are a b cup or smaller and can get away without support. if i would have seen this is the store, i would have passed over it. however, i was too lazy to return so i am wearing it. it's comfortable so that's a redeeming quality. i would not recommend for larger chested ladies, though!",
#   'ratings': 2,
#   'product_type': 'Intimate',
#   'sentiment': "{'neg': 0.048, 'neu': 0.619, 'pos': 0.333, 'compound': 0.9287}",
#   'sentiment_score': 0.9287,
#   'rating_match': 'Incorrect'},
#  {'product_id': 862,
#   'age': 31,
#   'review_title': 'Boring front, great back',
#   'review': 'This tank fit well and i loved the ruffle in the back and how it layed. but the front was not a good look and i will be retuning it.',
#   'ratings': 3,
#   'product_type': 'Tops',
#   'sentiment': "{'neg': 0.0, 'neu': 0.38, 'pos': 0.62, 'compound': 0.886}",
#   'sentiment_score': 0.886,
#   'rating_match': 'Incorrect'},
#  {'product_id': 1095,
#   'age': 36,
#   'review_title': 'unknown',
#   'review': "I got this in the petite length, size o, and it fit just right. i like that i didn't have to have it altered in the length; can wear with flats with plenty of clearance to the floor from the bottom hem. my only beef with the design is the height of the waist. i personally think that the elastic waistband looks cheap, and really needs to be concealed with a belt, yet because it sits so high, literally right under the bustline, it's a tricky one to pull off. i have a wide belt that sort of does th",
#   'ratings': 4,
#   'product_type': 'Dresses',
#   'sentiment': "{'neg': 0.034, 'neu': 0.861, 'pos': 0.105, 'compound': 0.5267}",
#   'sentiment_score': 0.5267,
#   'rating_match': 'Correct'},
#  {'product_id': 368,
#   'age': 52,
#   'review_title': 'Soft and comfortable',
#   'review': "I've been looking for bralettes that provide some support but not binding/tight for night time and casual wear. this is a light weight bra, could be a little more supportive. pretty color, with nice lines. only downside is the retailer tag on the back - itchy (i need to remove it.)",
#   'ratings': 4,
#   'product_type': 'Intimate',
#   'sentiment': "{'neg': 0.113, 'neu': 0.552, 'pos': 0.335, 'compound': 0.7923}",
#   'sentiment_score': 0.7923,
#   'rating_match': 'Correct'},
#  {'product_id': 1095,
#   'age': 41,
#   'review_title': 'Gorgeous dress!',
#   'review': "This dress is simply beautiful and stunning. it is so figure flattering and i can't wait to wear it. size small worked for me, and since i'm tall it fell right to my ankle which is perfect for me. i could not be happier with the purchase and the keyhole in the back is a beautiful detail.",
#   'ratings': 5,
#   'product_type': 'Dresses',
#   'sentiment': "{'neg': 0.0, 'neu': 0.503, 'pos': 0.497, 'compound': 0.9628}",
#   'sentiment_score': 0.9628,
#   'rating_match': 'Correct'},
#  {'product_id': 368,
#   'age': 36,
#   'review_title': 'Itchy tags',
#   'review': "3 tags sewn in, 2 small (about 1'' long) and 1 huge (about 2'' x 3''). very itchy so i cut them out. then the thread left behind was plasticy and even more itchy! how can you make an intimates item with such itchy tags? not comfortable at all! also - i love bralettes and wear them all the time including to work. i am a b cup. however, this one is so thin and flimsy that it gives no support even to a b cup - so for me this would only be a lounging bralette - if it wasn't so itchy!",
#   'ratings': 1,
#   'product_type': 'Intimate',
#   'sentiment': "{'neg': 0.194, 'neu': 0.574, 'pos': 0.231, 'compound': 0.6124}",
#   'sentiment_score': 0.6124,
#   'rating_match': 'Incorrect'},
#  {'product_id': 862,
#   'age': 28,
#   'review_title': 'Must have',
#   'review': "I recently got this on sale after looking at it forever on my wish list. i'm so happy with it. its very comfortable and just long enough for my torso (5'3). the pattern on the front is very flattering.",
#   'ratings': 5,
#   'product_type': 'Tops',
#   'sentiment': "{'neg': 0.0, 'neu': 0.52, 'pos': 0.48, 'compound': 0.9001}",
#   'sentiment_score': 0.9001,
#   'rating_match': 'Correct'},
#  {'product_id': 862,
#   'age': 57,
#   'review_title': 'Cute top! love the brand',
#   'review': 'Very comfortable shirt, light weight top with lovely floral colors. great for spring/summer with white jeans. love everything one september makes!',
#   'ratings': 5,
#   'product_type': 'Tops',
#   'sentiment': "{'neg': 0.0, 'neu': 0.411, 'pos': 0.589, 'compound': 0.9531}",
#   'sentiment_score': 0.9531,
#   'rating_match': 'Correct'},
#  {'product_id': 862,
#   'age': 43,
#   'review_title': 'Love this top',
#   'review': 'Loved this top and was really happy to find it on sale!',
#   'ratings': 5,
#   'product_type': 'Tops',
#   'sentiment': "{'neg': 0.0, 'neu': 0.236, 'pos': 0.764, 'compound': 0.8655}",
#   'sentiment_score': 0.8655,
#   'rating_match': 'Correct'},
#  {'product_id': 862,
#   'age': 58,
#   'review_title': 'unknown',
#   'review': "Beautiful top, but delicate! i wore it to school and the straps on my backpack caused some pilling. other than that it is beautiful and vibrant! just make sure you aren't doing/wearing anything that will rub it continuously since the fabric is delicate",
#   'ratings': 4,
#   'product_type': 'Tops',
#   'sentiment': "{'neg': 0.0, 'neu': 0.442, 'pos': 0.558, 'compound': 0.9403}",
#   'sentiment_score': 0.9403,
#   'rating_match': 'Correct'},
#  {'product_id': 862,
#   'age': 60,
#   'review_title': 'Super cute and unique top',
#   'review': "Just received this in the mail, tried it on and am smitten. i'm usually a l, but sometimes i'm a xl (if no stretch), in retailer tops. i bought this one in l and i'm sure glad i did. very flowy, stretchy and comfortable. i also bought the meda lace top from one september and they are very similar expect this is more of a t-shirt and the other is more of a blouse. i almost think i could've gotten a m in this because there is a lot of extra fabric at the chest which is usually never the issue for me",
#   'ratings': 4,
#   'product_type': 'Tops',
#   'sentiment': "{'neg': 0.0, 'neu': 0.73, 'pos': 0.27, 'compound': 0.9136}",
#   'sentiment_score': 0.9136,
#   'rating_match': 'Correct'},
#  {'product_id': 862,
#   'age': 40,
#   'review_title': 'Beautiful top',
#   'review': 'Love this top! i kept eyeing it online and wavering on size, since my post-baby body is a little wonky. i went with the xsp, and miraculously, it works perfectly! so, i would say it does run just a little large..... i love the length, and usually do not go with petite sizes at retailer because i like the longer lengths of the regular. but this is perfect on me, and there is give up top, so it looks lovely. and it is very soft and comfortable. this will be a go-to top this season!',
#   'ratings': 5,
#   'product_type': 'Tops',
#   'sentiment': "{'neg': 0.025, 'neu': 0.493, 'pos': 0.482, 'compound': 0.9829}",
#   'sentiment_score': 0.9829,
#   'rating_match': 'Correct'},
#  {'product_id': 862,
#   'age': 37,
#   'review_title': 'I wanted to love this top...',
#   'review': 'I really loved this top online and wanted to love it in person. it is soft and the patter is okay in person. the neckline is higher than i am used to. also, there are two buttons in the back that must be unbuttoned in order to wear the top. it is difficult to button them behind your neck with the top on. unfortunately i had to return this item...',
#   'ratings': 2,
#   'product_type': 'Tops',
#   'sentiment': "{'neg': 0.11, 'neu': 0.518, 'pos': 0.372, 'compound': 0.8917}",
#   'sentiment_score': 0.8917,
#   'rating_match': 'Incorrect'},
#  {'product_id': 1078,
#   'age': 56,
#   'review_title': 'Great summer fabric!',
#   'review': 'I really wanted this to work. alas, it had a strange fit for me. the straps would not stay up, and it had a weird fit under the breast. it worked standing up, but the minute i sat down it fell off my shoulders. the fabric was beautiful! and i loved that it had pockets.',
#   'ratings': 3,
#   'product_type': 'Dresses',
#   'sentiment': "{'neg': 0.174, 'neu': 0.446, 'pos': 0.38, 'compound': 0.8375}",
#   'sentiment_score': 0.8375,
#   'rating_match': 'Incorrect'},
#  {'product_id': 845,
#   'age': 38,
#   'review_title': 'Cute, but massive sweep',
#   'review': 'This top is so cute, but it is massively babydoll shaped (a- line) which is not apparent from the pictures. i measured the xs i have and the chest is about 42" and sweep is over 70". i would definitely keep this top if it hung straighter. the craftsmanship is lovely and fabric is so natural and handwoven looking. i\'m thinking about asking my tailor if she can take the sides in, but that might ruin it as the fabric layout is cut and proportioned to this swing style.',
#   'ratings': 4,
#   'product_type': 'Tops',
#   'sentiment': "{'neg': 0.11, 'neu': 0.598, 'pos': 0.292, 'compound': 0.8271}",
#   'sentiment_score': 0.8271,
#   'rating_match': 'Correct'},
#  {'product_id': 822,
#   'age': 36,
#   'review_title': 'Short and boxy',
#   'review': "Why do designers keep making crop tops??!! i can't imagine this would be flattering on anyone, especially someone average height and well endowed on top. i looked like a football player. the pattern and fabric are gorgeous, so if you are like 4' tall and super tiny and can fit xxs this may work? i am between a 6-8 and fit a small and it was huge on me and almost was bigger at the bottom than the top. such a weird cut. there is a cami underneath so if it rides up that will show but that is so 80s",
#   'ratings': 2,
#   'product_type': 'Tops',
#   'sentiment': "{'neg': 0.085, 'neu': 0.486, 'pos': 0.43, 'compound': 0.9699}",
#   'sentiment_score': 0.9699,
#   'rating_match': 'Incorrect'},
#  {'product_id': 850,
#   'age': 27,
#   'review_title': 'Beautiful design',
#   'review': "I have a short torso and this works well for me. 34c, bought the 0. there's not much stretch to the fabric so it is fitted to my chest, but not in an uncomfortable way. definitely doesn't hang and have extra fabric like on the model. \r\n\r\nzipper goes almost all the way down to the bottom so it's easier to get on and off which makes up for the lack of stretch n the fabric.\r\n\r\nunlike another reviewer, i found it went really well with navy pants and i wore it to a business meeting under a blazer. wi",
#   'ratings': 5,
#   'product_type': 'Tops',
#   'sentiment': "{'neg': 0.088, 'neu': 0.698, 'pos': 0.214, 'compound': 0.7216}",
#   'sentiment_score': 0.7216,
#   'rating_match': 'Correct'},
#  {'product_id': 866,
#   'age': 47,
#   'review_title': 'unknown',
#   'review': "I love this top. it is loose and comfortable. it is not sheer so you don't need a cami. it runs a little large so size down if you want a more tailored fit. 1 criticism, it catches on sharp jewelry or belts and can pull if you are not careful.",
#   'ratings': 4,
#   'product_type': 'Tops',
#   'sentiment': "{'neg': 0.155, 'neu': 0.416, 'pos': 0.429, 'compound': 0.804}",
#   'sentiment_score': 0.804,
#   'rating_match': 'Correct'},
#  {'product_id': 1081,
#   'age': 59,
#   'review_title': 'unknown',
#   'review': 'I passed up this dress so many times in the store and finally tried it on today because i wanted a casual dress while traveling in the cape. i was surprised how much cuter it is on than on hanger. i sized down to get a more fitting look and really made a difference for me in style. i was not a fan of the way it looked so loose on model. it looks really cute fitted and a bit sexy even. it is lined and very comfy and can be dressed up a but for work with a cardi. i believe i will get a lot of wear',
#   'ratings': 5,
#   'product_type': 'Dresses',
#   'sentiment': "{'neg': 0.04, 'neu': 0.681, 'pos': 0.279, 'compound': 0.9134}",
#   'sentiment_score': 0.9134,
#   'rating_match': 'Correct'},
#  {'product_id': 845,
#   'age': 48,
#   'review_title': 'Very very cute but a lot of fabric',
#   'review': 'I am so drawn to baby doll and boxy shirts so i immediately tried this on in the store. i am petite and only 5\'2", so usually shirts with a lot of fabric swallow me whole but this one was still cute. there is a lot more fabric than the picture lets on, but i think it is still super cute and flattering. i would definitely check the size chart and read comments to see if someone with your same size description has recommended a specific size for your body type. i am petite and weigh about 110 lbs',
#   'ratings': 5,
#   'product_type': 'Tops',
#   'sentiment': "{'neg': 0.0, 'neu': 0.716, 'pos': 0.284, 'compound': 0.9403}",
#   'sentiment_score': 0.9403,
#   'rating_match': 'Correct'},
#  {'product_id': 1082,
#   'age': 31,
#   'review_title': 'Runs large in top and waist',
#   'review': 'I would have loved this dress if the bust and waist were just a little more fitted. i am 32c and the top was too big. fit perfectly on hips. the lace material means it cannot be easily altered, so i chose to return the dress. i would have definitely kept it if it were a better fit.',
#   'ratings': 4,
#   'product_type': 'Dresses',
#   'sentiment': "{'neg': 0.049, 'neu': 0.46, 'pos': 0.49, 'compound': 0.9531}",
#   'sentiment_score': 0.9531,
#   'rating_match': 'Correct'},
#  {'product_id': 850,
#   'age': 28,
#   'review_title': 'Zipper broke',
#   'review': "The zipper broke on this piece the first time i wore it. very disappointing since i love the design. i'm actually going to try to replace the zipper myself with something stronger, but annoying that it's come to that.",
#   'ratings': 2,
#   'product_type': 'Tops',
#   'sentiment': "{'neg': 0.285, 'neu': 0.492, 'pos': 0.223, 'compound': -0.2263}",
#   'sentiment_score': -0.2263,
#   'rating_match': 'Correct'},
#  {'product_id': 836,
#   'age': 47,
#   'review_title': 'Obsessed',
#   'review': 'I usually size up with this brand. small was perfect for me at 135lbs. this top has a luxurious but casual feel and beautiful. i am obsessed and want to wear it everyday. it wears a little long and drapey but a little tight where it rolls up in the arms.',
#   'ratings': 5,
#   'product_type': 'Tops',
#   'sentiment': "{'neg': 0.054, 'neu': 0.545, 'pos': 0.401, 'compound': 0.8689}",
#   'sentiment_score': 0.8689,
#   'rating_match': 'Correct'},
#  {'product_id': 1081,
#   'age': 62,
#   'review_title': 'So cute...but dry clean?!',
#   'review': "This dress is adorable - it's a perfect casual look for summer and the quality is nice with the lining (though still overpriced, in my opinion). the tie detail is somewhat adjustable, and i found my normal size s to fit fine (5'7, 128#). where this gets me is the fact that it's dry clean...totally doesn't make sense for a dress that is essentially a fancy tshirt for summer. i might bring it back for that alone, since i originally planned to wear it a lot. :(",
#   'ratings': 4,
#   'product_type': 'Dresses',
#   'sentiment': "{'neg': 0.036, 'neu': 0.681, 'pos': 0.283, 'compound': 0.9153}",
#   'sentiment_score': 0.9153,
#   'rating_match': 'Correct'},
#  {'product_id': 1072,
#   'age': 68,
#   'review_title': 'Elegant classic dress',
#   'review': 'I am usually a petite 6 but since this dress did not come in petites i tried on 4 and it fit. i\'m 5\'1" -112lbs so dress hit rt below knee -will have it hemmed up a bit do not so overwhelming.\n\nthis dress looks stunning on! great vibrant color ( i have dark hair) makes this classic elegant dress look contemporary and stylish. when i tried it on in store, salesperson and others who happen to see it on me raved and told me to grab it! i did and am glad.\n\ni plan to wear it this spring for my daughte',
#   'ratings': 5,
#   'product_type': 'Dresses',
#   'sentiment': "{'neg': 0.0, 'neu': 0.687, 'pos': 0.313, 'compound': 0.9565}",
#   'sentiment_score': 0.9565,
#   'rating_match': 'Correct'},
#  {'product_id': 863,
#   'age': 61,
#   'review_title': 'unknown',
#   'review': 'Loved this top. great design. comfortable and unique. soft material',
#   'ratings': 5,
#   'product_type': 'Tops',
#   'sentiment': "{'neg': 0.0, 'neu': 0.234, 'pos': 0.766, 'compound': 0.9201}",
#   'sentiment_score': 0.9201,
#   'rating_match': 'Correct'},
#  {'product_id': 1133,
#   'age': 33,
#   'review_title': 'Cute parka!',
# ...
#   'ratings': 3,
#   'product_type': 'Tops',
#   'sentiment': "{'neg': 0.149, 'neu': 0.547, 'pos': 0.304, 'compound': 0.8807}",
#   'sentiment_score': 0.8807,
#   'rating_match': 'Incorrect'},
#  {'product_id': 936,
#   'age': 40,
#   'review_title': 'Cozy cut',
#   'review': 'Love this as a lightweight coat for cool to cold days. i love the squishy soft feel of the material. it works well with sweaters. love the deep pockets which works with my iphone plus and wallet. i love how simple and practical this coat is. the hood when not used as a hood makes a nice collar for the neck and head.',
#   'ratings': 5,
#   'product_type': 'Tops',
#   'sentiment': "{'neg': 0.0, 'neu': 0.52, 'pos': 0.48, 'compound': 0.975}",
#   'sentiment_score': 0.975,
#   'rating_match': 'Correct'},
#  {'product_id': 1094,
#   'age': 27,
#   'review_title': 'Slimming, cute',
#   'review': "I have broader shoulders and thick arms, this dress does an amazing job slimming my arms and not making me appear top heavy!\r\ni'm 5'4 125 lbs, the xs fit perfectly",
#   'ratings': 5,
#   'product_type': 'Dresses',
#   'sentiment': "{'neg': 0.0, 'neu': 0.565, 'pos': 0.435, 'compound': 0.9062}",
#   'sentiment_score': 0.9062,
#   'rating_match': 'Correct'},
#  {'product_id': 936,
#   'age': 28,
#   'review_title': 'Beautiful design but not great quality.',
#   'review': "I'll start with saying that it's a beautiful coat- i get tons of compliments and love the color. it runs a little big but it's meant to have to a slouchy, oversized quality to it. my only complaint is that i've had it for about 3 weeks and already one button has completely fallen off and the two inside fasteners already feel loose and very delicate. there's no extra buttons to replace the old one with and i'm worried more of the coat is going to fall apart. super bummed about the construction qu",
#   'ratings': 3,
#   'product_type': 'Tops',
#   'sentiment': "{'neg': 0.186, 'neu': 0.574, 'pos': 0.24, 'compound': 0.6815}",
#   'sentiment_score': 0.6815,
#   'rating_match': 'Incorrect'},
#  {'product_id': 1154,
#   'age': 44,
#   'review_title': 'Worth every penny!',
#   'review': 'This bra is so well made and fits beautifully.',
#   'ratings': 5,
#   'product_type': 'Intimate',
#   'sentiment': "{'neg': 0.0, 'neu': 0.341, 'pos': 0.659, 'compound': 0.7003}",
#   'sentiment_score': 0.7003,
#   'rating_match': 'Correct'},
#  {'product_id': 936,
#   'age': 47,
#   'review_title': 'Lovely',
#   'review': 'Snapped this sweet puppy up at my local retailer-in the sale room!!!!! it is beyond fabulous and the coral color is divine!!!! brightens up the drearriest of days-i did size down. i am short and the small sleeves were way too long on my 5ft3in frame. it runs a bit large but if you were to wear a heavier something under it i could see getting your "normal" size. the quality is great and the style is just lovely. great jacket-love love love',
#   'ratings': 5,
#   'product_type': 'Tops',
#   'sentiment': "{'neg': 0.0, 'neu': 0.501, 'pos': 0.499, 'compound': 0.9871}",
#   'sentiment_score': 0.9871,
#   'rating_match': 'Correct'},
#  {'product_id': 936,
#   'age': 42,
#   'review_title': 'Beautiful coat',
#   'review': 'Love this coat - great fall piece! i bought the green color and it looks as shown in the picture. great retailer purchase!',
#   'ratings': 5,
#   'product_type': 'Tops',
#   'sentiment': "{'neg': 0.0, 'neu': 0.47, 'pos': 0.53, 'compound': 0.9246}",
#   'sentiment_score': 0.9246,
#   'rating_match': 'Correct'},
#  {'product_id': 936,
#   'age': 31,
#   'review_title': 'Love this!',
#   'review': "I bought it to mainly wear as a coat but i think it'd be great with some leggings and boots as well. if you want a more structured look go a size smaller. i plan on wearing this more as outer wear so i went with large. the coral is beautiful",
#   'ratings': 5,
#   'product_type': 'Tops',
#   'sentiment': "{'neg': 0.0, 'neu': 0.637, 'pos': 0.363, 'compound': 0.886}",
#   'sentiment_score': 0.886,
#   'rating_match': 'Correct'},
#  {'product_id': 868,
#   'age': 26,
#   'review_title': 'Cute tunic',
#   'review': 'This tunic is very nice. flattering, good design, worn in winter and spring, and fits well. i have a curvy figure, and this fits well. i wish it came in more colors.it does show flaws slightly but fits well and is stretchy.',
#   'ratings': 4,
#   'product_type': 'Tops',
#   'sentiment': "{'neg': 0.064, 'neu': 0.439, 'pos': 0.497, 'compound': 0.9153}",
#   'sentiment_score': 0.9153,
#   'rating_match': 'Correct'},
#  {'product_id': 854,
#   'age': 59,
#   'review_title': 'Misleading picture!',
#   'review': "The top i received was large, really long in length, pockets in the front along the seam, and lots of volume in the back without any princess seams to give it shape. the id #'s matched, but that's about it. returned!",
#   'ratings': 1,
#   'product_type': 'Tops',
#   'sentiment': "{'neg': 0.0, 'neu': 0.921, 'pos': 0.079, 'compound': 0.2023}",
#   'sentiment_score': 0.2023,
#   'rating_match': 'Incorrect'},
#  {'product_id': 936,
#   'age': 33,
#   'review_title': 'Cozy, flattering, and practical',
#   'review': "At first, i thought this sweater might be too boxy, but fastened at the waist, it's very flattering and the collar is face-framing, and the coral in particular (really more of a mango sorbet shade) is unexpected but cheery for winter.\n\nbut the big selling point is the warmth and the giant pockets. brought a new puppy home just after christmas, and this sweater is perfect for layering for late- night trips out with an easy place to stash my phone and treats. bought it in coral and pink.",
#   'ratings': 5,
#   'product_type': 'Tops',
#   'sentiment': "{'neg': 0.0, 'neu': 0.716, 'pos': 0.284, 'compound': 0.9382}",
#   'sentiment_score': 0.9382,
#   'rating_match': 'Correct'},
#  {'product_id': 949,
#   'age': 47,
#   'review_title': 'Great sweater!',
#   'review': "I love this sweater! pros: great shape (it's supposed to be a little oversized looking), great color (i have the ivory and it's beautiful), and fits well (the sweater looks boxy until you put it on and it flows in all the right places). the sweater is not soft. that is my only con. it looks so soft in the photos, but the sweater i received is not at all soft and cozy. it is warm. it will be great for the winter - great pair with leggings, skirts or just jeans.",
#   'ratings': 4,
#   'product_type': 'Tops',
#   'sentiment': "{'neg': 0.0, 'neu': 0.529, 'pos': 0.471, 'compound': 0.9826}",
#   'sentiment_score': 0.9826,
#   'rating_match': 'Correct'},
#  {'product_id': 1094,
#   'age': 46,
#   'review_title': 'Beautiful',
#   'review': 'I love this dress. will be wearing it for the first time tomorrow. it fits well. the neck line is a bit low on me. i think it would look best on someone with more of a chest than i have. i will be wearing a winter white infinity scarf with it (as shown on model). i am 5\' 6.5" and 120 lbs and the small is just right.',
#   'ratings': 5,
#   'product_type': 'Dresses',
#   'sentiment': "{'neg': 0.054, 'neu': 0.674, 'pos': 0.272, 'compound': 0.8555}",
#   'sentiment_score': 0.8555,
#   'rating_match': 'Correct'},
#  {'product_id': 936,
#   'age': 24,
#   'review_title': 'Best sweater jacket!',
#   'review': "Love this sweater jacket! super comfortable and warm. i am 5'2 and i got a xs petite. it fit perfectly both in length and in the sleeve. the green color is super rich and is perfect for the season. it's easy to wear it up and wear it down. i appreciate that it's not super bulky, which was what i was afraid of. my favorite jacket of the season so far.",
#   'ratings': 5,
#   'product_type': 'Tops',
#   'sentiment': "{'neg': 0.0, 'neu': 0.292, 'pos': 0.708, 'compound': 0.9921}",
#   'sentiment_score': 0.9921,
#   'rating_match': 'Correct'},
#  {'product_id': 1047,
#   'age': 34,
#   'review_title': 'Not for every body type',
#   'review': 'I am 5\'6", 130 lbs with an athletic body type and i ordered a size small. these were really baggy in the thigh/quadricep area and made my thighs look bulky. the fabric quality is very nice and i like the idea of them for curvier body types. my son commented that they looked like pajama pants and i agreed.',
#   'ratings': 2,
#   'product_type': 'Bottoms',
#   'sentiment': "{'neg': 0.0, 'neu': 0.739, 'pos': 0.261, 'compound': 0.836}",
#   'sentiment_score': 0.836,
#   'rating_match': 'Incorrect'},
#  {'product_id': 1083,
#   'age': 53,
#   'review_title': 'Best for staright figures',
#   'review': 'This is a beautiful dress but if you have any hips at all you may find it difficult to find the right size. i usually wear a 0-2 p and found that that the op was too snug on the bottom while the 2p was too loose on top. ( for reference 32-26-35). so if you are perfectly proportioned it could work for you.\r\nalso, note that this is a pencil dress....very slim fitting.....probably best suited for a cocktail party.',
#   'ratings': 4,
#   'product_type': 'Dresses',
#   'sentiment': "{'neg': 0.097, 'neu': 0.565, 'pos': 0.339, 'compound': 0.9186}",
#   'sentiment_score': 0.9186,
#   'rating_match': 'Correct'},
#  {'product_id': 949,
#   'age': 38,
#   'review_title': 'Cute sweater!',
#   'review': 'Purchased this sweater in the blue color which is a gray/blue. it runs large as the xs is still quite roomy on me in the body. although the arms are more snug. great quality.',
#   'ratings': 5,
#   'product_type': 'Tops',
#   'sentiment': "{'neg': 0.0, 'neu': 0.796, 'pos': 0.204, 'compound': 0.6249}",
#   'sentiment_score': 0.6249,
#   'rating_match': 'Correct'},
#  {'product_id': 949,
#   'age': 58,
#   'review_title': 'So happy i ordered this!',
#   'review': "I bought this as a birthday gift for my daughter, and i am so glad i did. the colors are beautiful, and the material is so soft. i'm sure she's going to love it!",
#   'ratings': 5,
#   'product_type': 'Tops',
#   'sentiment': "{'neg': 0.0, 'neu': 0.356, 'pos': 0.644, 'compound': 0.946}",
#   'sentiment_score': 0.946,
#   'rating_match': 'Correct'},
#  {'product_id': 909,
#   'age': 33,
#   'review_title': 'Wanted to love it, but just kinda like it',
#   'review': "So when i saw a sweater with a big llama face on the front of it, i knew it must be mine. i ordered it and eagerly awaited its arrival. while the llama print and color of the sweater are ah-mazing, the fit of the sweater leaves something to be desired. i'm a 36 dd and mostly a size l, so that's what i ordered. it wasn't snug, but it didn't have the cut to pull off the oversized drapey look, so the areas where it was loose looked...strange. the sleeves were really long too, but i could have rolle",
#   'ratings': 3,
#   'product_type': 'Tops',
#   'sentiment': "{'neg': 0.096, 'neu': 0.766, 'pos': 0.138, 'compound': 0.4935}",
#   'sentiment_score': 0.4935,
#   'rating_match': 'Incorrect'},
#  {'product_id': 949,
#   'age': 67,
#   'review_title': 'Lovely top',
#   'review': 'I fell in love with this top (sweater) before it could even be ordered - was on model for pants that were available to order. in any case, i later ordered the blue motif online and the colors are even more beautiful in person. the blue also contains fibers of wine - so very pretty. the gray is a soft shade. the quality is lovely too. the only cons are that the seater is rather heavy, but should be great for colder winter months and the zipper on the back is quite conspicuous. however, that said,',
#   'ratings': 5,
#   'product_type': 'Tops',
#   'sentiment': "{'neg': 0.0, 'neu': 0.656, 'pos': 0.344, 'compound': 0.9682}",
#   'sentiment_score': 0.9682,
#   'rating_match': 'Correct'},
#  {'product_id': 873,
#   'age': 32,
#   'review_title': 'Comfy & cute',
#   'review': "Love the feminine styling of a classic tunic tee! i'll wear it with black leggings this fall. super cute to wear casually or dress up a bit with some jewelry and/or a scarf.",
#   'ratings': 5,
#   'product_type': 'Tops',
#   'sentiment': "{'neg': 0.092, 'neu': 0.49, 'pos': 0.418, 'compound': 0.875}",
#   'sentiment_score': 0.875,
#   'rating_match': 'Correct'},
#  {'product_id': 873,
#   'age': 59,
#   'review_title': 'unknown',
#   'review': 'This top is full of amazing details. the photos really don\'t do it justice. it is very flowy and does run large but is so pretty and soft and in beautiful shades of blue. i bought a small and it is fairly long in back on my 5\'5" frame but because of the detailing...it just works.',
#   'ratings': 5,
#   'product_type': 'Tops',
#   'sentiment': "{'neg': 0.085, 'neu': 0.559, 'pos': 0.355, 'compound': 0.864}",
#   'sentiment_score': 0.864,
#   'rating_match': 'Correct'},
#  {'product_id': 909,
#   'age': 82,
#   'review_title': 'Love this sweater',
#   'review': 'Unlike the first three reviews, i loved this sweater. the colors were beautiful and i paired it with green cords. i did not find the sweater to be itchy but very comfortable. fits trus to size.',
#   'ratings': 5,
#   'product_type': 'Tops',
#   'sentiment': "{'neg': 0.077, 'neu': 0.515, 'pos': 0.408, 'compound': 0.875}",
#   'sentiment_score': 0.875,
#   'rating_match': 'Correct'},
#  {'product_id': 1083,
#   'age': 46,
#   'review_title': 'Classically byron lars',
#   'review': "Great fit even for busty women. ordered an 8 because i usually need the room in the chest area on dresses.(36d-dd) fit nicely without being tight. might have been able to size down but i didn't want to risk being too tight. flattering especially on curves. nice for contemporary office or special occasion. if you like his designs, you won't be disappointed!",
#   'ratings': 5,
#   'product_type': 'Dresses',
#   'sentiment': "{'neg': 0.023, 'neu': 0.46, 'pos': 0.517, 'compound': 0.9742}",
#   'sentiment_score': 0.9742,
#   'rating_match': 'Correct'},
#  {'product_id': 873,
#   'age': 34,
#   'review_title': 'Great blouse',
#   'review': "Love this top, purchased it in the coral color now i'm definitely wanting it in the blue since it is such a great blouse for transitioning into fall. the weight of the top it good since i live in south texas so definitely needing lightweight long sleeves for our weather. i'm sure when the time comes adding a long cardigan or blazer over it as needed for the cooler weather it will look great. fit true to size.",
#   'ratings': 5,
#   'product_type': 'Tops',
#   'sentiment': "{'neg': 0.0, 'neu': 0.501, 'pos': 0.499, 'compound': 0.9833}",
#   'sentiment_score': 0.9833,
#   'rating_match': 'Correct'},
#  {'product_id': 1172,
#   'age': 25,
#   'review_title': 'unknown',
#   'review': "Absolutely love this suit. the bottoms are very comfortable and covers everything id like it to. it does not ride up at all, which almost never happens with swim suits. i'm going to order this in a different color next season. i paired the bottoms with the peplum top and received many compliments.",
#   'ratings': 5,
#   'product_type': 'Intimate',
#   'sentiment': "{'neg': 0.0, 'neu': 0.619, 'pos': 0.381, 'compound': 0.9299}",
#   'sentiment_score': 0.9299,
#   'rating_match': 'Correct'},
#  {'product_id': 1083,
#   'age': 35,
#   'review_title': 'Awesome dress',
#   'review': 'I just love this dress.  took me ordering a number of sizes- petite and regular to find the best fit.  i might still have the top altered.  i received a lot of compliements.  work it with some black leather wedges for daytime/work.',
#   'ratings': 5,
#   'product_type': 'Dresses',
#   'sentiment': "{'neg': 0.0, 'neu': 0.562, 'pos': 0.438, 'compound': 0.9186}",
#   'sentiment_score': 0.9186,
#   'rating_match': 'Correct'},
#  {'product_id': 949,
#   'age': 42,
#   'review_title': 'Beautiful!',
#   'review': 'I got the purple color and absolutely love it. i am 5\'2" but decided against the petite size and i wanted it to be a bit longer. i also went with the xxs as the xs was a bit too loose on the arm. it was definitely a splurge to buy the sweater but it looked so lovely!',
#   'ratings': 5,
#   'product_type': 'Tops',
#   'sentiment': "{'neg': 0.067, 'neu': 0.612, 'pos': 0.321, 'compound': 0.8655}",
#   'sentiment_score': 0.8655,
#   'rating_match': 'Correct'},
#  {'product_id': 949,
#   'age': 35,
#   'review_title': 'Cute sweater!',
#   'review': "Love the color! very soft. unique look. can't wait to wear it this fall",
#   'ratings': 5,
#   'product_type': 'Tops',
#   'sentiment': "{'neg': 0.0, 'neu': 0.656, 'pos': 0.344, 'compound': 0.6369}",
#   'sentiment_score': 0.6369,
#   'rating_match': 'Correct'},
#  ...]

# %%
def dataconveter():
    product_data=pd.read_csv(r"/Users/rasikagulhane/Desktop/Customer_Rating_Reviews/data/modeified_raw_reviews.csv")

    data=product_data

    product_list = [['Product_ID','Age','Title','Text_Review','Rating','Type','sentiment','sentiment_score','rating_match']]


    # Iterate over the rows of the DataFrame
    for index, row in data.iterrows():
        # Construct an object with 'product_name' and 'review' attributes
        obj = {

                'product_id': row['Product_ID'],
                'age': row['Age'],
                'review_title': row['Title'],
                'review':row['Text_Review'],
                'ratings':row['Rating'],
                'product_type': row['Type'],
                'sentiment': row['sentiment'],
                'sentiment_score': row['sentiment_score'],
                'rating_match': row['rating_match']
            
            }
        # Append the object to the list
        product_list.append(obj)

# %%
for entry in product_list[:3]:  # Print the first 3 entries to understand the structure
    print(entry)
# Out:
# ['Product_ID', 'Age', 'Title', 'Text_Review', 'Rating', 'Type', 'sentiment', 'sentiment_score', 'rating_match']
# {'product_id': 767, 'age': 33, 'review_title': 'unknown', 'review': 'Absolutely wonderful - silky and sexy and comfortable', 'ratings': 4, 'product_type': 'Intimate', 'sentiment': "{'neg': 0.0, 'neu': 0.154, 'pos': 0.846, 'compound': 0.8991}", 'sentiment_score': 0.8991, 'rating_match': 'Correct'}
# {'product_id': 1080, 'age': 34, 'review_title': 'unknown', 'review': 'Love this dress!  it\'s sooo pretty.  i happened to find it in a store, and i\'m glad i did bc i never would have ordered it online bc it\'s petite.  i bought a petite and am 5\'8".  i love the length on me- hits just a little below the knee.  would definitely be a true midi on someone who is truly petite.', 'ratings': 5, 'product_type': 'Dresses', 'sentiment': "{'neg': 0.0, 'neu': 0.514, 'pos': 0.486, 'compound': 0.971}", 'sentiment_score': 0.971, 'rating_match': 'Correct'}

# %%
docs = []
for entry in product_list[1:]:  # Skip the first item which contains the column headers
    metadata = {
        'product_id': entry['product_id'],
        'age': entry['age'],
        'review_title': entry['review_title'],
        'ratings': entry['ratings'],
        'product_type': entry['product_type'],
        'sentiment': entry['sentiment'],
        'sentiment_score': entry['sentiment_score'],
        'rating_match': entry['rating_match']
    }
    doc = Document(page_content=entry['review'], metadata=metadata)
    docs.append(doc)

# %%
def dataconveter():
    product_data=pd.read_csv(r"/Users/rasikagulhane/Desktop/Customer_Rating_Reviews/data/modeified_raw_reviews.csv")

    data=product_data

    product_list = [['Product_ID','Age','Title','Text_Review','Rating','Type','sentiment','sentiment_score','rating_match']]




    # Iterate over the rows of the DataFrame
    for index, row in data.iterrows():
        # Construct an object with 'product_name' and 'review' attributes
        obj = {


                'product_id': row['Product_ID'],
                'age': row['Age'],
                'review_title': row['Title'],
                'review':row['Text_Review'],
                'ratings':row['Rating'],
                'product_type': row['Type'],
                'sentiment': row['sentiment'],
                'sentiment_score': row['sentiment_score'],
                'rating_match': row['rating_match']
            
             
            }
        # Append the object to the list
        product_list.append(obj)

        
            
    docs = []
    for entry in product_list[1:]:  # Skip the first item which contains the column headers
        metadata = {
            'product_id': entry['product_id'],
            'age': entry['age'],
            'review_title': entry['review_title'],
            'ratings': entry['ratings'],
            'product_type': entry['product_type'],
            'sentiment': entry['sentiment'],
            'sentiment_score': entry['sentiment_score'],
            'rating_match': entry['rating_match']
    }
        doc = Document(page_content=entry['review'], metadata=metadata)
        docs.append(doc)

    return docs

# %%
dataconveter()
# Out:
# [Document(page_content='Absolutely wonderful - silky and sexy and comfortable', metadata={'product_id': 767, 'age': 33, 'review_title': 'unknown', 'ratings': 4, 'product_type': 'Intimate', 'sentiment': "{'neg': 0.0, 'neu': 0.154, 'pos': 0.846, 'compound': 0.8991}", 'sentiment_score': 0.8991, 'rating_match': 'Correct'}),
#  Document(page_content='Love this dress!  it\'s sooo pretty.  i happened to find it in a store, and i\'m glad i did bc i never would have ordered it online bc it\'s petite.  i bought a petite and am 5\'8".  i love the length on me- hits just a little below the knee.  would definitely be a true midi on someone who is truly petite.', metadata={'product_id': 1080, 'age': 34, 'review_title': 'unknown', 'ratings': 5, 'product_type': 'Dresses', 'sentiment': "{'neg': 0.0, 'neu': 0.514, 'pos': 0.486, 'compound': 0.971}", 'sentiment_score': 0.971, 'rating_match': 'Correct'}),
#  Document(page_content='I had such high hopes for this dress and really wanted it to work for me. i initially ordered the petite small (my usual size) but i found this to be outrageously small. so small in fact that i could not zip it up! i reordered it in petite medium, which was just ok. overall, the top half was comfortable and fit nicely, but the bottom half had a very tight under layer and several somewhat cheap (net) over layers. imo, a major design flaw was the net over layer sewn directly into the zipper - it c', metadata={'product_id': 1077, 'age': 60, 'review_title': 'Some major design flaws', 'ratings': 3, 'product_type': 'Dresses', 'sentiment': "{'neg': 0.038, 'neu': 0.693, 'pos': 0.269, 'compound': 0.9062}", 'sentiment_score': 0.9062, 'rating_match': 'Incorrect'}),
#  Document(page_content="I love, love, love this jumpsuit. it's fun, flirty, and fabulous! every time i wear it, i get nothing but great compliments!", metadata={'product_id': 1049, 'age': 50, 'review_title': 'My favorite buy!', 'ratings': 5, 'product_type': 'Bottoms', 'sentiment': "{'neg': 0.171, 'neu': 0.185, 'pos': 0.644, 'compound': 0.9464}", 'sentiment_score': 0.9464, 'rating_match': 'Correct'}),
#  Document(page_content='This shirt is very flattering to all due to the adjustable front tie. it is the perfect length to wear with leggings and it is sleeveless so it pairs well with any cardigan. love this shirt!!!', metadata={'product_id': 847, 'age': 47, 'review_title': 'Flattering shirt', 'ratings': 5, 'product_type': 'Tops', 'sentiment': "{'neg': 0.0, 'neu': 0.494, 'pos': 0.506, 'compound': 0.9062}", 'sentiment_score': 0.9062, 'rating_match': 'Correct'}),
#  Document(page_content='I love tracy reese dresses, but this one is not for the very petite. i am just under 5 feet tall and usually wear a 0p in this brand. this dress was very pretty out of the package but its a lot of dress. the skirt is long and very full so it overwhelmed my small frame. not a stranger to alterations, shortening and narrowing the skirt would take away from the embellishment of the garment. i love the color and the idea of the style but it just did not work on me. i returned this dress.', metadata={'product_id': 1080, 'age': 49, 'review_title': 'Not for the very petite', 'ratings': 2, 'product_type': 'Dresses', 'sentiment': "{'neg': 0.0, 'neu': 0.738, 'pos': 0.262, 'compound': 0.9153}", 'sentiment_score': 0.9153, 'rating_match': 'Incorrect'}),
#  Document(page_content='I aded this in my basket at hte last mintue to see what it would look like in person. (store pick up). i went with teh darkler color only because i am so pale :-) hte color is really gorgeous, and turns out it mathced everythiing i was trying on with it prefectly. it is a little baggy on me and hte xs is hte msallet size (bummer, no petite). i decided to jkeep it though, because as i said, it matvehd everything. my ejans, pants, and the 3 skirts i waas trying on (of which i ]kept all ) oops.', metadata={'product_id': 858, 'age': 39, 'review_title': 'Cagrcoal shimmer fun', 'ratings': 5, 'product_type': 'Tops', 'sentiment': "{'neg': 0.048, 'neu': 0.827, 'pos': 0.125, 'compound': 0.6361}", 'sentiment_score': 0.6361, 'rating_match': 'Correct'}),
#  Document(page_content="I ordered this in carbon for store pick up, and had a ton of stuff (as always) to try on and used this top to pair (skirts and pants). everything went with it. the color is really nice charcoal with shimmer, and went well with pencil skirts, flare pants, etc. my only compaint is it is a bit big, sleeves are long and it doesn't go in petite. also a bit loose for me, but no xxs... so i kept it and wil ldecide later since the light color is already sold out in hte smallest size...", metadata={'product_id': 858, 'age': 39, 'review_title': 'Shimmer, surprisingly goes with lots', 'ratings': 4, 'product_type': 'Tops', 'sentiment': "{'neg': 0.041, 'neu': 0.835, 'pos': 0.124, 'compound': 0.5709}", 'sentiment_score': 0.5709, 'rating_match': 'Correct'}),
#  Document(page_content='I love this dress. i usually get an xs but it runs a little snug in bust so i ordered up a size. very flattering and feminine with the usual retailer flair for style.', metadata={'product_id': 1077, 'age': 24, 'review_title': 'Flattering', 'ratings': 5, 'product_type': 'Dresses', 'sentiment': "{'neg': 0.0, 'neu': 0.698, 'pos': 0.302, 'compound': 0.7579}", 'sentiment_score': 0.7579, 'rating_match': 'Correct'}),
#  Document(page_content='I\'m 5"5\' and 125 lbs. i ordered the s petite to make sure the length wasn\'t too long. i typically wear an xs regular in retailer dresses. if you\'re less busty (34b cup or smaller), a s petite will fit you perfectly (snug, but not tight). i love that i could dress it up for a party, or down for work. i love that the tulle is longer then the fabric underneath.', metadata={'product_id': 1077, 'age': 34, 'review_title': 'Such a fun dress!', 'ratings': 5, 'product_type': 'Dresses', 'sentiment': "{'neg': 0.0, 'neu': 0.614, 'pos': 0.386, 'compound': 0.9643}", 'sentiment_score': 0.9643, 'rating_match': 'Correct'}),
#  Document(page_content='Dress runs small esp where the zipper area runs. i ordered the sp which typically fits me and it was very tight! the material on the top looks and feels very cheap that even just pulling on it will cause it to rip the fabric. pretty disappointed as it was going to be my christmas dress this year! needless to say it will be going back.', metadata={'product_id': 1077, 'age': 53, 'review_title': "Dress looks like it's made of cheap material", 'ratings': 3, 'product_type': 'Dresses', 'sentiment': "{'neg': 0.084, 'neu': 0.782, 'pos': 0.135, 'compound': 0.2263}", 'sentiment_score': 0.2263, 'rating_match': 'Incorrect'}),
#  Document(page_content='This dress is perfection! so pretty and flattering.', metadata={'product_id': 1095, 'age': 39, 'review_title': 'unknown', 'ratings': 5, 'product_type': 'Dresses', 'sentiment': "{'neg': 0.0, 'neu': 0.098, 'pos': 0.902, 'compound': 0.8481}", 'sentiment_score': 0.8481, 'rating_match': 'Correct'}),
#  Document(page_content='More and more i find myself reliant on the reviews written by savvy shoppers before me and for the most past, they are right on in their estimation of the product. in the case of this dress-if it had not been for the reveiws-i doubt i would have even tried this. the dress is beautifully made, lined and reminiscent of the old retailer quality. it is lined in the solid periwinkle-colored fabric that matches the outer fabric print. tts and very form-fitting. falls just above the knee and does not rid', metadata={'product_id': 1095, 'age': 53, 'review_title': 'Perfect!!!', 'ratings': 5, 'product_type': 'Dresses', 'sentiment': "{'neg': 0.058, 'neu': 0.785, 'pos': 0.157, 'compound': 0.5106}", 'sentiment_score': 0.5106, 'rating_match': 'Correct'}),
#  Document(page_content='Bought the black xs to go under the larkspur midi dress because they didn\'t bother lining the skirt portion (grrrrrrrrrrr).\r\nmy stats are 34a-28/29-36 and the xs fit very smoothly around the chest and was flowy around my lower half, so i would say it\'s running big.\r\nthe straps are very pretty and it could easily be nightwear too.\r\ni\'m 5\'6" and it came to just below my knees.', metadata={'product_id': 767, 'age': 44, 'review_title': 'Runs big', 'ratings': 5, 'product_type': 'Intimate', 'sentiment': "{'neg': 0.05, 'neu': 0.722, 'pos': 0.229, 'compound': 0.7867}", 'sentiment_score': 0.7867, 'rating_match': 'Correct'}),
#  Document(page_content='This is a nice choice for holiday gatherings. i like that the length grazes the knee so it is conservative enough for office related gatherings. the size small fit me well - i am usually a size 2/4 with a small bust. in my opinion it runs small and those with larger busts will definitely have to size up (but then perhaps the waist will be too big). the problem with this dress is the quality. the fabrics are terrible. the delicate netting type fabric on the top layer of skirt got stuck in the zip', metadata={'product_id': 1077, 'age': 50, 'review_title': 'Pretty party dress with some issues', 'ratings': 3, 'product_type': 'Dresses', 'sentiment': "{'neg': 0.126, 'neu': 0.58, 'pos': 0.295, 'compound': 0.8176}", 'sentiment_score': 0.8176, 'rating_match': 'Incorrect'}),
#  Document(page_content="I took these out of the package and wanted them to fit so badly, but i could tell before i put them on that they wouldn't. these are for an hour-glass figure. i am more straight up and down. the waist was way too small for my body shape and even if i sized up, i could tell they would still be tight in the waist and too roomy in the hips - for me. that said, they are really nice. sturdy, linen-like fabric, pretty color, well made. i hope they make someone very happy!", metadata={'product_id': 1065, 'age': 47, 'review_title': 'Nice, but not for my body', 'ratings': 4, 'product_type': 'Bottoms', 'sentiment': "{'neg': 0.086, 'neu': 0.597, 'pos': 0.317, 'compound': 0.914}", 'sentiment_score': 0.914, 'rating_match': 'Correct'}),
#  Document(page_content="Material and color is nice.  the leg opening is very large.  i am 5'1 (100#) and the length hits me right above my ankle.  with a leg opening the size of my waist and hem line above my ankle, and front pleats to make me fluffy, i think you can imagine that it is not a flattering look.  if you are at least average height or taller, this may look good on you.", metadata={'product_id': 1065, 'age': 34, 'review_title': 'You need to be at least average height, or taller', 'ratings': 3, 'product_type': 'Bottoms', 'sentiment': "{'neg': 0.0, 'neu': 0.795, 'pos': 0.205, 'compound': 0.7906}", 'sentiment_score': 0.7906, 'rating_match': 'Incorrect'}),
#  Document(page_content="Took a chance on this blouse and so glad i did. i wasn't crazy about how the blouse is photographed on the model. i paired it whit white pants and it worked perfectly. crisp and clean is how i would describe it. launders well. fits great. drape is perfect. wear tucked in or out - can't go wrong.", metadata={'product_id': 853, 'age': 41, 'review_title': 'Looks great with white pants', 'ratings': 5, 'product_type': 'Tops', 'sentiment': "{'neg': 0.0, 'neu': 0.443, 'pos': 0.557, 'compound': 0.9761}", 'sentiment_score': 0.9761, 'rating_match': 'Correct'}),
#  Document(page_content="A flattering, super cozy coat.  will work well for cold, dry days and will look good with jeans or a dressier outfit.  i am 5' 5'', about 135 and the small fits great.", metadata={'product_id': 1120, 'age': 32, 'review_title': 'Super cute and cozy', 'ratings': 5, 'product_type': 'Jackets', 'sentiment': "{'neg': 0.0, 'neu': 0.459, 'pos': 0.541, 'compound': 0.936}", 'sentiment_score': 0.936, 'rating_match': 'Correct'}),
#  Document(page_content="I love the look and feel of this tulle dress. i was looking for something different, but not over the top for new year's eve. i'm small chested and the top of this dress is form fitting for a flattering look. once i steamed the tulle, it was perfect! i ordered an xsp. length was perfect too.", metadata={'product_id': 1077, 'age': 47, 'review_title': 'Stylish and comfortable', 'ratings': 5, 'product_type': 'Dresses', 'sentiment': "{'neg': 0.0, 'neu': 0.557, 'pos': 0.443, 'compound': 0.9477}", 'sentiment_score': 0.9477, 'rating_match': 'Correct'}),
#  Document(page_content="If this product was in petite, i would get the petite. the regular is a little long on me but a tailor can do a simple fix on that. \r\n\r\nfits nicely! i'm 5'4, 130lb and pregnant so i bough t medium to grow into. \r\n\r\nthe tie can be front or back so provides for some nice flexibility on form fitting.", metadata={'product_id': 847, 'age': 33, 'review_title': 'Cute, crisp shirt', 'ratings': 4, 'product_type': 'Tops', 'sentiment': "{'neg': 0.0, 'neu': 0.755, 'pos': 0.245, 'compound': 0.7964}", 'sentiment_score': 0.7964, 'rating_match': 'Correct'}),
#  Document(page_content="I'm upset because for the price of the dress, i thought it was embroidered! no, that is a print on the fabric. i think i cried a little when i opened the box. it is still ver pretty. i would say it is true to size, it is a tad bit big on me, but i am very tiny, but i can still get away with it. the color is vibrant. the style is unique. skirt portion is pretty poofy. i keep going back and forth on it mainly because of the price, although the quality is definitely there. except i wish it were emb", metadata={'product_id': 1080, 'age': 55, 'review_title': "I'm torn!", 'ratings': 4, 'product_type': 'Dresses', 'sentiment': "{'neg': 0.084, 'neu': 0.627, 'pos': 0.289, 'compound': 0.9153}", 'sentiment_score': 0.9153, 'rating_match': 'Correct'}),
#  Document(page_content="First of all, this is not pullover styling. there is a side zipper. i wouldn't have purchased it if i knew there was a side zipper because i have a large bust and side zippers are next to impossible for me.\n\nsecond of all, the tulle feels and looks cheap and the slip has an awkward tight shape underneath.\n\nnot at all what is looks like or is described as. sadly will be returning, but i'm sure i will find something to exchange it for!", metadata={'product_id': 1077, 'age': 31, 'review_title': 'Not what it looks like', 'ratings': 2, 'product_type': 'Dresses', 'sentiment': "{'neg': 0.107, 'neu': 0.777, 'pos': 0.117, 'compound': 0.1027}", 'sentiment_score': 0.1027, 'rating_match': 'Incorrect'}),
#  Document(page_content="Cute little dress fits tts. it is a little high waisted. good length for my 5'9 height. i like the dress, i'm just not in love with it. i dont think it looks or feels cheap. it appears just as pictured.", metadata={'product_id': 1077, 'age': 34, 'review_title': "Like it, but don't love it.", 'ratings': 3, 'product_type': 'Dresses', 'sentiment': "{'neg': 0.0, 'neu': 0.606, 'pos': 0.394, 'compound': 0.9069}", 'sentiment_score': 0.9069, 'rating_match': 'Incorrect'}),
#  Document(page_content="I love this shirt because when i first saw it, i wasn't sure if it was a shirt or dress. since it is see-through if you wear it like a dress you will need a slip or wear it with leggings. i bought a slip, wore the tie in the back, and rocked it with white wedges. you could also wear it as a vest. be careful with the buttons. i haven't had any fall off yet, but i feel like they will. overall it's great for any occasion and it's fun to wear!", metadata={'product_id': 847, 'age': 55, 'review_title': 'Versatile', 'ratings': 5, 'product_type': 'Tops', 'sentiment': "{'neg': 0.036, 'neu': 0.628, 'pos': 0.336, 'compound': 0.9454}", 'sentiment_score': 0.9454, 'rating_match': 'Correct'}),
#  Document(page_content='Loved the material, but i didnt really look at how long the dress was before i purchased both a large and a medium. im 5\'5" and there was atleast 5" of material at my feet. the gaps in the front are much wider than they look. felt like the dress just fell flat. both were returned. im usually a large and the med fit better. 36d 30 in jeans', metadata={'product_id': 697, 'age': 31, 'review_title': 'Falls flat', 'ratings': 3, 'product_type': 'Intimate', 'sentiment': "{'neg': 0.0, 'neu': 0.724, 'pos': 0.276, 'compound': 0.8957}", 'sentiment_score': 0.8957, 'rating_match': 'Incorrect'}),
#  Document(page_content="I have been waiting for this sweater coat to ship for weeks and i was so excited for it to arrive. this coat is not true to size and made me look short and squat. the sleeves are very wide (although long). as a light weight fall coat the sleeves don't need to be as wide because you wouldn't be layerng too much underneath. the buttons need to be moved at least three inches in for a nicer fit. i thought about redoing the buttons myself but the sleeves looked even more out of proportion with a tigh", metadata={'product_id': 949, 'age': 33, 'review_title': 'Huge disappointment', 'ratings': 2, 'product_type': 'Tops', 'sentiment': "{'neg': 0.0, 'neu': 0.798, 'pos': 0.202, 'compound': 0.8625}", 'sentiment_score': 0.8625, 'rating_match': 'Incorrect'}),
#  Document(page_content="The colors weren't what i expected either. the dark blue is much more vibrant and i just couldn't find anything to really go with it. fabric is thick and good quality. has nice weight and movement to it. the skirt just wasn't for me, in the end.", metadata={'product_id': 1003, 'age': 31, 'review_title': 'Loved, but returned', 'ratings': 4, 'product_type': 'Bottoms', 'sentiment': "{'neg': 0.0, 'neu': 0.687, 'pos': 0.313, 'compound': 0.8442}", 'sentiment_score': 0.8442, 'rating_match': 'Correct'}),
#  Document(page_content="I have several of goodhyouman shirts and i get so many compliments on them. especially the one that says forehead kisses are underrated. don't hesitate. buy this shirt. you won't be sorry.....", metadata={'product_id': 684, 'age': 53, 'review_title': 'Great shirt!!!', 'ratings': 5, 'product_type': 'Intimate', 'sentiment': "{'neg': 0.0, 'neu': 0.608, 'pos': 0.392, 'compound': 0.7927}", 'sentiment_score': 0.7927, 'rating_match': 'Correct'}),
#  Document(page_content="This sweater is so comfy and classic - it balances a quirky hand-knit look with a beautiful color and practical fit. it is a bit cropped and boxy as part of the style, and as others mentioned, there are gaps in the knit that make it see-through. in my opinion this makes it perfect for layering! i like having a longer camisole showing underneath, or wearing it over a little dress. it's warm but still thin enough to fit under a jacket or coat.", metadata={'product_id': 4, 'age': 28, 'review_title': 'Great layering piece', 'ratings': 5, 'product_type': 'Tops', 'sentiment': "{'neg': 0.0, 'neu': 0.677, 'pos': 0.323, 'compound': 0.9405}", 'sentiment_score': 0.9405, 'rating_match': 'Correct'}),
#  Document(page_content='Beautifully made pants and on trend with the flared crop. so much cuter in person. love these!', metadata={'product_id': 1060, 'age': 33, 'review_title': 'unknown', 'ratings': 5, 'product_type': 'Bottoms', 'sentiment': "{'neg': 0.0, 'neu': 0.385, 'pos': 0.615, 'compound': 0.9042}", 'sentiment_score': 0.9042, 'rating_match': 'Correct'}),
#  Document(page_content="I never would have given these pants a second look online, in person they are much cuter! the stripes are brighter and the fit more flattering. the crop has a cute flare which is right on trend. this brand has always run small for me, i am 5'8 about 140lbs and carry some chubbiness in the belly. i paired it with a collarless loose navy blazer", metadata={'product_id': 1060, 'age': 46, 'review_title': 'Cuter in oerson!', 'ratings': 5, 'product_type': 'Bottoms', 'sentiment': "{'neg': 0.053, 'neu': 0.628, 'pos': 0.319, 'compound': 0.886}", 'sentiment_score': 0.886, 'rating_match': 'Correct'}),
#  Document(page_content='These pants are even better in person. the only downside is that they need to be dry cleaned.', metadata={'product_id': 1060, 'age': 21, 'review_title': 'Love these pants', 'ratings': 5, 'product_type': 'Bottoms', 'sentiment': "{'neg': 0.183, 'neu': 0.55, 'pos': 0.266, 'compound': 0.2263}", 'sentiment_score': 0.2263, 'rating_match': 'Correct'}),
#  Document(page_content='I ordered this 3 months ago, and it finally came off back order. a huge disappointment. the fit wasn&#39;t so much the issue for me. the quality of the wool is subpar. someone else mentioned a &quot;felted wool&quot;...i guess, is that what you call it?  it does literally feel like felt! super thin, itchy, doesn&#39;t drape very well, and feels cheap (made in china). i got it on sale, but still not worth what i paid. definitely going back.', metadata={'product_id': 949, 'age': 36, 'review_title': 'Mehh', 'ratings': 2, 'product_type': 'Tops', 'sentiment': "{'neg': 0.091, 'neu': 0.607, 'pos': 0.302, 'compound': 0.8885}", 'sentiment_score': 0.8885, 'rating_match': 'Incorrect'}),
#  Document(page_content='This is such a neat dress. the color is great and the fabric is super soft. i am tall so the long length was an added bonus. it definitely needs something underneath since the front gaps. i am going to pair it with a funky tank top, necklaces and boots. super cute!!', metadata={'product_id': 697, 'age': 39, 'review_title': 'Love this dress!', 'ratings': 5, 'product_type': 'Intimate', 'sentiment': "{'neg': 0.03, 'neu': 0.41, 'pos': 0.559, 'compound': 0.9764}", 'sentiment_score': 0.9764, 'rating_match': 'Correct'}),
#  Document(page_content="Wouldn't have given them a second look but tried them on in store of a whim. love, love!!", metadata={'product_id': 1060, 'age': 65, 'review_title': 'Lovely!', 'ratings': 4, 'product_type': 'Bottoms', 'sentiment': "{'neg': 0.0, 'neu': 0.455, 'pos': 0.545, 'compound': 0.8555}", 'sentiment_score': 0.8555, 'rating_match': 'Correct'}),
#  Document(page_content='This is a comfortable skirt that can span seasons easily. while not the most exciting design, it is a good work skirt that can be paired with many tops.', metadata={'product_id': 1002, 'age': 29, 'review_title': 'unknown', 'ratings': 4, 'product_type': 'Bottoms', 'sentiment': "{'neg': 0.0, 'neu': 0.346, 'pos': 0.654, 'compound': 0.9337}", 'sentiment_score': 0.9337, 'rating_match': 'Correct'}),
#  Document(page_content='Just ordered this in a small for me (5\'6", 135, size 4) and medium for my mom (5\'3", 130, size 8) and it is gorgeous - beautifully draped, all the weight/warmth i\'ll need for houston fall and winter, looks polished snapped or unsnapped. age-appropriate for both my mom (60\'s) and myself (30\'s). will look amazing with skinny jeans or leggings. we ordered the gray which is true to the photos.', metadata={'product_id': 949, 'age': 38, 'review_title': 'Beautifully cut lightweight coat', 'ratings': 5, 'product_type': 'Tops', 'sentiment': "{'neg': 0.058, 'neu': 0.644, 'pos': 0.297, 'compound': 0.91}", 'sentiment_score': 0.91, 'rating_match': 'Correct'}),
#  Document(page_content='Super cute and comfy pull over. sizing is accurate. material has a little bit of stretch.', metadata={'product_id': 684, 'age': 36, 'review_title': 'unknown', 'ratings': 5, 'product_type': 'Intimate', 'sentiment': "{'neg': 0.0, 'neu': 0.537, 'pos': 0.463, 'compound': 0.7845}", 'sentiment_score': 0.7845, 'rating_match': 'Correct'}),
#  Document(page_content='Great casual top with flare. looks cute with grey pilcro stet jeans. flattering with peplum in back. nice cut for shoulders and neckline.', metadata={'product_id': 862, 'age': 59, 'review_title': 'unknown', 'ratings': 5, 'product_type': 'Tops', 'sentiment': "{'neg': 0.075, 'neu': 0.32, 'pos': 0.605, 'compound': 0.9169}", 'sentiment_score': 0.9169, 'rating_match': 'Correct'}),
#  Document(page_content='Pretty and unique. great with jeans or i have worn it to work with slacks and heels. the colors, print, and embroidery are lovely. reasonably priced!', metadata={'product_id': 862, 'age': 47, 'review_title': 'unknown', 'ratings': 4, 'product_type': 'Tops', 'sentiment': "{'neg': 0.094, 'neu': 0.429, 'pos': 0.476, 'compound': 0.872}", 'sentiment_score': 0.872, 'rating_match': 'Correct'}),
#  Document(page_content="This is a beautiful top. it's unique and not so ordinary. i bought my usual medium and i found that it fits tight across my chest. although i had a baby this year and i am nursing, so that could be why. if i bought again i would size up.", metadata={'product_id': 862, 'age': 40, 'review_title': 'unknown', 'ratings': 5, 'product_type': 'Tops', 'sentiment': "{'neg': 0.0, 'neu': 0.759, 'pos': 0.241, 'compound': 0.6908}", 'sentiment_score': 0.6908, 'rating_match': 'Correct'}),
#  Document(page_content='This poncho is so cute i love the plaid check design, the colors look like sorbet & cream and it will pair well with a turtleneck and jeans or pencil skirt and heels. i love this look for fall and it can roll right into spring. great buy!!', metadata={'product_id': 910, 'age': 23, 'review_title': 'Soft & lovely', 'ratings': 5, 'product_type': 'Tops', 'sentiment': "{'neg': 0.0, 'neu': 0.499, 'pos': 0.501, 'compound': 0.9643}", 'sentiment_score': 0.9643, 'rating_match': 'Correct'}),
#  Document(page_content='First, this is thermal ,so naturally i didn\'t expect super sheer, but it is. really sheer light fabric. i like it, but be prepared for considering who you might run into if you walk around the house in it. second, it is large. i ordered the size 0 and it\'s a nice oversized fit for my 5\'3" 125 pounds. i wouldn\'t want to go larger. along with being sheer, the fabric is easily stretched, which i don\'t mind in this case. finally, the color. it looks white on my monitor and shows a colorful blue dot', metadata={'product_id': 89, 'age': 67, 'review_title': 'Some things you should know...', 'ratings': 4, 'product_type': 'Intimate', 'sentiment': "{'neg': 0.073, 'neu': 0.723, 'pos': 0.203, 'compound': 0.7738}", 'sentiment_score': 0.7738, 'rating_match': 'Correct'}),
#  Document(page_content='Tried this on today at my local retailer and had to have it. it is so comfortable and flattering. it\'s too bad the picture online has the model tucking it into the skirt because you can\'t see the ruching across the front. a little dressier alternative to a plain tee and reasonably priced for retailer. 5\'8"" and i generally wear a 6, the small fit well. will probably be back for the black!', metadata={'product_id': 862, 'age': 48, 'review_title': 'Beautiful!', 'ratings': 5, 'product_type': 'Tops', 'sentiment': "{'neg': 0.082, 'neu': 0.679, 'pos': 0.239, 'compound': 0.6908}", 'sentiment_score': 0.6908, 'rating_match': 'Correct'}),
#  Document(page_content='I bought this item from online... the fit on the model looked a little loose but when i got mine it seemed a bit tight! so i took it back to the store & ordered a larger size. for the sale price this is a great top.', metadata={'product_id': 862, 'age': 43, 'review_title': 'Love the two tone design', 'ratings': 4, 'product_type': 'Tops', 'sentiment': "{'neg': 0.068, 'neu': 0.646, 'pos': 0.286, 'compound': 0.7501}", 'sentiment_score': 0.7501, 'rating_match': 'Correct'}),
#  Document(page_content="I love this top. i wear it all the time.  the problem is that you can tell i wear it all the time as the fabric has started to fade.  i'd still recommend it as it is so comfortable.", metadata={'product_id': 862, 'age': 40, 'review_title': 'unknown', 'ratings': 5, 'product_type': 'Tops', 'sentiment': "{'neg': 0.11, 'neu': 0.408, 'pos': 0.482, 'compound': 0.8442}", 'sentiment_score': 0.8442, 'rating_match': 'Correct'}),
#  Document(page_content='Very comfortable, material is good, cut out on sleeves flattering', metadata={'product_id': 823, 'age': 52, 'review_title': 'unknown', 'ratings': 5, 'product_type': 'Tops', 'sentiment': "{'neg': 0.167, 'neu': 0.159, 'pos': 0.675, 'compound': 0.7506}", 'sentiment_score': 0.7506, 'rating_match': 'Correct'}),
#  Document(page_content="This sweater is perfect for fall...it's roomy, warm, super comfy and the color really pops.", metadata={'product_id': 910, 'age': 56, 'review_title': 'Love the color!', 'ratings': 5, 'product_type': 'Tops', 'sentiment': "{'neg': 0.0, 'neu': 0.424, 'pos': 0.576, 'compound': 0.8591}", 'sentiment_score': 0.8591, 'rating_match': 'Correct'}),
#  Document(page_content="Really cute top! the embroidery on the collar & bib of this top is beautiful and unique, received lots of compliments & questions about where i got it. i'm rather busty up top and the medium fit well, a small probably would've fit better but it's still super adorable.", metadata={'product_id': 862, 'age': 33, 'review_title': 'Love the embroidery!', 'ratings': 5, 'product_type': 'Tops', 'sentiment': "{'neg': 0.0, 'neu': 0.338, 'pos': 0.662, 'compound': 0.9838}", 'sentiment_score': 0.9838, 'rating_match': 'Correct'}),
#  Document(page_content="This is a cute top that can transition easily from summer to fall. it fits well, nice print and it's comfortable. i tried this on in the store, but did not purchase it because the color washed me out. this is not the best color for a blonde. would look much better on a brunette. if this was in a different color i most likely would have purchased it.", metadata={'product_id': 862, 'age': 46, 'review_title': 'Cute for fall', 'ratings': 4, 'product_type': 'Tops', 'sentiment': "{'neg': 0.0, 'neu': 0.483, 'pos': 0.517, 'compound': 0.9661}", 'sentiment_score': 0.9661, 'rating_match': 'Correct'}),
#  Document(page_content='I absolutely love this bib tee! it\'s probably my favorite retailer purchase of all time. i\'m 5\'7", 140 pounds and the small was a perfect fit for me. i typically wear either a s or m tops.', metadata={'product_id': 862, 'age': 41, 'review_title': 'Love', 'ratings': 5, 'product_type': 'Tops', 'sentiment': "{'neg': 0.0, 'neu': 0.469, 'pos': 0.531, 'compound': 0.9516}", 'sentiment_score': 0.9516, 'rating_match': 'Correct'}),
#  Document(page_content='Love the color and style, but material snags easily', metadata={'product_id': 1104, 'age': 39, 'review_title': 'unknown', 'ratings': 3, 'product_type': 'Dresses', 'sentiment': "{'neg': 0.0, 'neu': 0.377, 'pos': 0.623, 'compound': 0.765}", 'sentiment_score': 0.765, 'rating_match': 'Incorrect'}),
#  Document(page_content="Very soft and comfortable. the shirt has an unusual, asymmetrical seam that appears along the front, right-hand side of the garment. (the model is positioned so that you can't see this detail from the picture. i attached a picture that includes the front seam.) i actually like the seam - it creates more visual interest, and adds a little bit of ruching that helps hide my belly. the cowl neck is very well done - there are two layers that form the cowl, and i've found that it means wardrobe malfun", metadata={'product_id': 862, 'age': 39, 'review_title': 'Flattering and comfortable', 'ratings': 5, 'product_type': 'Tops', 'sentiment': "{'neg': 0.029, 'neu': 0.711, 'pos': 0.26, 'compound': 0.9124}", 'sentiment_score': 0.9124, 'rating_match': 'Correct'}),
#  Document(page_content="Nice top. armholes are a bit oversized but as an older woman, i'm picky about that. the print is pretty and unusual. it just didn't look great on me. there's a slight peplum in the back that hangs nicely. it's a lightweight tee fabric that's opaque. i tried it on with a black bra which was barely visible. great for warmer climates but there are so many gorgeous tops out now, that i decided to return since summer is winding down. i do recommend.", metadata={'product_id': 862, 'age': 66, 'review_title': 'Cute top', 'ratings': 4, 'product_type': 'Tops', 'sentiment': "{'neg': 0.106, 'neu': 0.532, 'pos': 0.362, 'compound': 0.9306}", 'sentiment_score': 0.9306, 'rating_match': 'Correct'}),
#  Document(page_content="This is an adorable top that i find to be extremely comfortable. i don't usually buy prints but this one is so feminine and looks great with dark wash jeans. i am a 36d and the medium was a perfect fit.", metadata={'product_id': 862, 'age': 61, 'review_title': 'Soft and cute as can be!', 'ratings': 5, 'product_type': 'Tops', 'sentiment': "{'neg': 0.0, 'neu': 0.426, 'pos': 0.574, 'compound': 0.9577}", 'sentiment_score': 0.9577, 'rating_match': 'Correct'}),
#  Document(page_content="I am pregnant and i thought this would be a great sleep bra. it's soft and fits okay, but it has zero support or shape. i would only buy if you are a b cup or smaller and can get away without support. if i would have seen this is the store, i would have passed over it. however, i was too lazy to return so i am wearing it. it's comfortable so that's a redeeming quality. i would not recommend for larger chested ladies, though!", metadata={'product_id': 368, 'age': 33, 'review_title': 'unknown', 'ratings': 2, 'product_type': 'Intimate', 'sentiment': "{'neg': 0.048, 'neu': 0.619, 'pos': 0.333, 'compound': 0.9287}", 'sentiment_score': 0.9287, 'rating_match': 'Incorrect'}),
#  Document(page_content='This tank fit well and i loved the ruffle in the back and how it layed. but the front was not a good look and i will be retuning it.', metadata={'product_id': 862, 'age': 31, 'review_title': 'Boring front, great back', 'ratings': 3, 'product_type': 'Tops', 'sentiment': "{'neg': 0.0, 'neu': 0.38, 'pos': 0.62, 'compound': 0.886}", 'sentiment_score': 0.886, 'rating_match': 'Incorrect'}),
#  Document(page_content="I got this in the petite length, size o, and it fit just right. i like that i didn't have to have it altered in the length; can wear with flats with plenty of clearance to the floor from the bottom hem. my only beef with the design is the height of the waist. i personally think that the elastic waistband looks cheap, and really needs to be concealed with a belt, yet because it sits so high, literally right under the bustline, it's a tricky one to pull off. i have a wide belt that sort of does th", metadata={'product_id': 1095, 'age': 36, 'review_title': 'unknown', 'ratings': 4, 'product_type': 'Dresses', 'sentiment': "{'neg': 0.034, 'neu': 0.861, 'pos': 0.105, 'compound': 0.5267}", 'sentiment_score': 0.5267, 'rating_match': 'Correct'}),
#  Document(page_content="I've been looking for bralettes that provide some support but not binding/tight for night time and casual wear. this is a light weight bra, could be a little more supportive. pretty color, with nice lines. only downside is the retailer tag on the back - itchy (i need to remove it.)", metadata={'product_id': 368, 'age': 52, 'review_title': 'Soft and comfortable', 'ratings': 4, 'product_type': 'Intimate', 'sentiment': "{'neg': 0.113, 'neu': 0.552, 'pos': 0.335, 'compound': 0.7923}", 'sentiment_score': 0.7923, 'rating_match': 'Correct'}),
#  Document(page_content="This dress is simply beautiful and stunning. it is so figure flattering and i can't wait to wear it. size small worked for me, and since i'm tall it fell right to my ankle which is perfect for me. i could not be happier with the purchase and the keyhole in the back is a beautiful detail.", metadata={'product_id': 1095, 'age': 41, 'review_title': 'Gorgeous dress!', 'ratings': 5, 'product_type': 'Dresses', 'sentiment': "{'neg': 0.0, 'neu': 0.503, 'pos': 0.497, 'compound': 0.9628}", 'sentiment_score': 0.9628, 'rating_match': 'Correct'}),
#  Document(page_content="3 tags sewn in, 2 small (about 1'' long) and 1 huge (about 2'' x 3''). very itchy so i cut them out. then the thread left behind was plasticy and even more itchy! how can you make an intimates item with such itchy tags? not comfortable at all! also - i love bralettes and wear them all the time including to work. i am a b cup. however, this one is so thin and flimsy that it gives no support even to a b cup - so for me this would only be a lounging bralette - if it wasn't so itchy!", metadata={'product_id': 368, 'age': 36, 'review_title': 'Itchy tags', 'ratings': 1, 'product_type': 'Intimate', 'sentiment': "{'neg': 0.194, 'neu': 0.574, 'pos': 0.231, 'compound': 0.6124}", 'sentiment_score': 0.6124, 'rating_match': 'Incorrect'}),
#  Document(page_content="I recently got this on sale after looking at it forever on my wish list. i'm so happy with it. its very comfortable and just long enough for my torso (5'3). the pattern on the front is very flattering.", metadata={'product_id': 862, 'age': 28, 'review_title': 'Must have', 'ratings': 5, 'product_type': 'Tops', 'sentiment': "{'neg': 0.0, 'neu': 0.52, 'pos': 0.48, 'compound': 0.9001}", 'sentiment_score': 0.9001, 'rating_match': 'Correct'}),
#  Document(page_content='Very comfortable shirt, light weight top with lovely floral colors. great for spring/summer with white jeans. love everything one september makes!', metadata={'product_id': 862, 'age': 57, 'review_title': 'Cute top! love the brand', 'ratings': 5, 'product_type': 'Tops', 'sentiment': "{'neg': 0.0, 'neu': 0.411, 'pos': 0.589, 'compound': 0.9531}", 'sentiment_score': 0.9531, 'rating_match': 'Correct'}),
#  Document(page_content='Loved this top and was really happy to find it on sale!', metadata={'product_id': 862, 'age': 43, 'review_title': 'Love this top', 'ratings': 5, 'product_type': 'Tops', 'sentiment': "{'neg': 0.0, 'neu': 0.236, 'pos': 0.764, 'compound': 0.8655}", 'sentiment_score': 0.8655, 'rating_match': 'Correct'}),
#  Document(page_content="Beautiful top, but delicate! i wore it to school and the straps on my backpack caused some pilling. other than that it is beautiful and vibrant! just make sure you aren't doing/wearing anything that will rub it continuously since the fabric is delicate", metadata={'product_id': 862, 'age': 58, 'review_title': 'unknown', 'ratings': 4, 'product_type': 'Tops', 'sentiment': "{'neg': 0.0, 'neu': 0.442, 'pos': 0.558, 'compound': 0.9403}", 'sentiment_score': 0.9403, 'rating_match': 'Correct'}),
#  Document(page_content="Just received this in the mail, tried it on and am smitten. i'm usually a l, but sometimes i'm a xl (if no stretch), in retailer tops. i bought this one in l and i'm sure glad i did. very flowy, stretchy and comfortable. i also bought the meda lace top from one september and they are very similar expect this is more of a t-shirt and the other is more of a blouse. i almost think i could've gotten a m in this because there is a lot of extra fabric at the chest which is usually never the issue for me", metadata={'product_id': 862, 'age': 60, 'review_title': 'Super cute and unique top', 'ratings': 4, 'product_type': 'Tops', 'sentiment': "{'neg': 0.0, 'neu': 0.73, 'pos': 0.27, 'compound': 0.9136}", 'sentiment_score': 0.9136, 'rating_match': 'Correct'}),
#  Document(page_content='Love this top! i kept eyeing it online and wavering on size, since my post-baby body is a little wonky. i went with the xsp, and miraculously, it works perfectly! so, i would say it does run just a little large..... i love the length, and usually do not go with petite sizes at retailer because i like the longer lengths of the regular. but this is perfect on me, and there is give up top, so it looks lovely. and it is very soft and comfortable. this will be a go-to top this season!', metadata={'product_id': 862, 'age': 40, 'review_title': 'Beautiful top', 'ratings': 5, 'product_type': 'Tops', 'sentiment': "{'neg': 0.025, 'neu': 0.493, 'pos': 0.482, 'compound': 0.9829}", 'sentiment_score': 0.9829, 'rating_match': 'Correct'}),
#  Document(page_content='I really loved this top online and wanted to love it in person. it is soft and the patter is okay in person. the neckline is higher than i am used to. also, there are two buttons in the back that must be unbuttoned in order to wear the top. it is difficult to button them behind your neck with the top on. unfortunately i had to return this item...', metadata={'product_id': 862, 'age': 37, 'review_title': 'I wanted to love this top...', 'ratings': 2, 'product_type': 'Tops', 'sentiment': "{'neg': 0.11, 'neu': 0.518, 'pos': 0.372, 'compound': 0.8917}", 'sentiment_score': 0.8917, 'rating_match': 'Incorrect'}),
#  Document(page_content='I really wanted this to work. alas, it had a strange fit for me. the straps would not stay up, and it had a weird fit under the breast. it worked standing up, but the minute i sat down it fell off my shoulders. the fabric was beautiful! and i loved that it had pockets.', metadata={'product_id': 1078, 'age': 56, 'review_title': 'Great summer fabric!', 'ratings': 3, 'product_type': 'Dresses', 'sentiment': "{'neg': 0.174, 'neu': 0.446, 'pos': 0.38, 'compound': 0.8375}", 'sentiment_score': 0.8375, 'rating_match': 'Incorrect'}),
#  Document(page_content='This top is so cute, but it is massively babydoll shaped (a- line) which is not apparent from the pictures. i measured the xs i have and the chest is about 42" and sweep is over 70". i would definitely keep this top if it hung straighter. the craftsmanship is lovely and fabric is so natural and handwoven looking. i\'m thinking about asking my tailor if she can take the sides in, but that might ruin it as the fabric layout is cut and proportioned to this swing style.', metadata={'product_id': 845, 'age': 38, 'review_title': 'Cute, but massive sweep', 'ratings': 4, 'product_type': 'Tops', 'sentiment': "{'neg': 0.11, 'neu': 0.598, 'pos': 0.292, 'compound': 0.8271}", 'sentiment_score': 0.8271, 'rating_match': 'Correct'}),
#  Document(page_content="Why do designers keep making crop tops??!! i can't imagine this would be flattering on anyone, especially someone average height and well endowed on top. i looked like a football player. the pattern and fabric are gorgeous, so if you are like 4' tall and super tiny and can fit xxs this may work? i am between a 6-8 and fit a small and it was huge on me and almost was bigger at the bottom than the top. such a weird cut. there is a cami underneath so if it rides up that will show but that is so 80s", metadata={'product_id': 822, 'age': 36, 'review_title': 'Short and boxy', 'ratings': 2, 'product_type': 'Tops', 'sentiment': "{'neg': 0.085, 'neu': 0.486, 'pos': 0.43, 'compound': 0.9699}", 'sentiment_score': 0.9699, 'rating_match': 'Incorrect'}),
#  Document(page_content="I have a short torso and this works well for me. 34c, bought the 0. there's not much stretch to the fabric so it is fitted to my chest, but not in an uncomfortable way. definitely doesn't hang and have extra fabric like on the model. \r\n\r\nzipper goes almost all the way down to the bottom so it's easier to get on and off which makes up for the lack of stretch n the fabric.\r\n\r\nunlike another reviewer, i found it went really well with navy pants and i wore it to a business meeting under a blazer. wi", metadata={'product_id': 850, 'age': 27, 'review_title': 'Beautiful design', 'ratings': 5, 'product_type': 'Tops', 'sentiment': "{'neg': 0.088, 'neu': 0.698, 'pos': 0.214, 'compound': 0.7216}", 'sentiment_score': 0.7216, 'rating_match': 'Correct'}),
#  Document(page_content="I love this top. it is loose and comfortable. it is not sheer so you don't need a cami. it runs a little large so size down if you want a more tailored fit. 1 criticism, it catches on sharp jewelry or belts and can pull if you are not careful.", metadata={'product_id': 866, 'age': 47, 'review_title': 'unknown', 'ratings': 4, 'product_type': 'Tops', 'sentiment': "{'neg': 0.155, 'neu': 0.416, 'pos': 0.429, 'compound': 0.804}", 'sentiment_score': 0.804, 'rating_match': 'Correct'}),
#  Document(page_content='I passed up this dress so many times in the store and finally tried it on today because i wanted a casual dress while traveling in the cape. i was surprised how much cuter it is on than on hanger. i sized down to get a more fitting look and really made a difference for me in style. i was not a fan of the way it looked so loose on model. it looks really cute fitted and a bit sexy even. it is lined and very comfy and can be dressed up a but for work with a cardi. i believe i will get a lot of wear', metadata={'product_id': 1081, 'age': 59, 'review_title': 'unknown', 'ratings': 5, 'product_type': 'Dresses', 'sentiment': "{'neg': 0.04, 'neu': 0.681, 'pos': 0.279, 'compound': 0.9134}", 'sentiment_score': 0.9134, 'rating_match': 'Correct'}),
#  Document(page_content='I am so drawn to baby doll and boxy shirts so i immediately tried this on in the store. i am petite and only 5\'2", so usually shirts with a lot of fabric swallow me whole but this one was still cute. there is a lot more fabric than the picture lets on, but i think it is still super cute and flattering. i would definitely check the size chart and read comments to see if someone with your same size description has recommended a specific size for your body type. i am petite and weigh about 110 lbs', metadata={'product_id': 845, 'age': 48, 'review_title': 'Very very cute but a lot of fabric', 'ratings': 5, 'product_type': 'Tops', 'sentiment': "{'neg': 0.0, 'neu': 0.716, 'pos': 0.284, 'compound': 0.9403}", 'sentiment_score': 0.9403, 'rating_match': 'Correct'}),
#  Document(page_content='I would have loved this dress if the bust and waist were just a little more fitted. i am 32c and the top was too big. fit perfectly on hips. the lace material means it cannot be easily altered, so i chose to return the dress. i would have definitely kept it if it were a better fit.', metadata={'product_id': 1082, 'age': 31, 'review_title': 'Runs large in top and waist', 'ratings': 4, 'product_type': 'Dresses', 'sentiment': "{'neg': 0.049, 'neu': 0.46, 'pos': 0.49, 'compound': 0.9531}", 'sentiment_score': 0.9531, 'rating_match': 'Correct'}),
#  Document(page_content="The zipper broke on this piece the first time i wore it. very disappointing since i love the design. i'm actually going to try to replace the zipper myself with something stronger, but annoying that it's come to that.", metadata={'product_id': 850, 'age': 28, 'review_title': 'Zipper broke', 'ratings': 2, 'product_type': 'Tops', 'sentiment': "{'neg': 0.285, 'neu': 0.492, 'pos': 0.223, 'compound': -0.2263}", 'sentiment_score': -0.2263, 'rating_match': 'Correct'}),
#  Document(page_content='I usually size up with this brand. small was perfect for me at 135lbs. this top has a luxurious but casual feel and beautiful. i am obsessed and want to wear it everyday. it wears a little long and drapey but a little tight where it rolls up in the arms.', metadata={'product_id': 836, 'age': 47, 'review_title': 'Obsessed', 'ratings': 5, 'product_type': 'Tops', 'sentiment': "{'neg': 0.054, 'neu': 0.545, 'pos': 0.401, 'compound': 0.8689}", 'sentiment_score': 0.8689, 'rating_match': 'Correct'}),
#  Document(page_content="This dress is adorable - it's a perfect casual look for summer and the quality is nice with the lining (though still overpriced, in my opinion). the tie detail is somewhat adjustable, and i found my normal size s to fit fine (5'7, 128#). where this gets me is the fact that it's dry clean...totally doesn't make sense for a dress that is essentially a fancy tshirt for summer. i might bring it back for that alone, since i originally planned to wear it a lot. :(", metadata={'product_id': 1081, 'age': 62, 'review_title': 'So cute...but dry clean?!', 'ratings': 4, 'product_type': 'Dresses', 'sentiment': "{'neg': 0.036, 'neu': 0.681, 'pos': 0.283, 'compound': 0.9153}", 'sentiment_score': 0.9153, 'rating_match': 'Correct'}),
#  Document(page_content='I am usually a petite 6 but since this dress did not come in petites i tried on 4 and it fit. i\'m 5\'1" -112lbs so dress hit rt below knee -will have it hemmed up a bit do not so overwhelming.\n\nthis dress looks stunning on! great vibrant color ( i have dark hair) makes this classic elegant dress look contemporary and stylish. when i tried it on in store, salesperson and others who happen to see it on me raved and told me to grab it! i did and am glad.\n\ni plan to wear it this spring for my daughte', metadata={'product_id': 1072, 'age': 68, 'review_title': 'Elegant classic dress', 'ratings': 5, 'product_type': 'Dresses', 'sentiment': "{'neg': 0.0, 'neu': 0.687, 'pos': 0.313, 'compound': 0.9565}", 'sentiment_score': 0.9565, 'rating_match': 'Correct'}),
#  Document(page_content='Loved this top. great design. comfortable and unique. soft material', metadata={'product_id': 863, 'age': 61, 'review_title': 'unknown', 'ratings': 5, 'product_type': 'Tops', 'sentiment': "{'neg': 0.0, 'neu': 0.234, 'pos': 0.766, 'compound': 0.9201}", 'sentiment_score': 0.9201, 'rating_match': 'Correct'}),
# ...
#  Document(page_content="I have broader shoulders and thick arms, this dress does an amazing job slimming my arms and not making me appear top heavy!\r\ni'm 5'4 125 lbs, the xs fit perfectly", metadata={'product_id': 1094, 'age': 27, 'review_title': 'Slimming, cute', 'ratings': 5, 'product_type': 'Dresses', 'sentiment': "{'neg': 0.0, 'neu': 0.565, 'pos': 0.435, 'compound': 0.9062}", 'sentiment_score': 0.9062, 'rating_match': 'Correct'}),
#  Document(page_content="I'll start with saying that it's a beautiful coat- i get tons of compliments and love the color. it runs a little big but it's meant to have to a slouchy, oversized quality to it. my only complaint is that i've had it for about 3 weeks and already one button has completely fallen off and the two inside fasteners already feel loose and very delicate. there's no extra buttons to replace the old one with and i'm worried more of the coat is going to fall apart. super bummed about the construction qu", metadata={'product_id': 936, 'age': 28, 'review_title': 'Beautiful design but not great quality.', 'ratings': 3, 'product_type': 'Tops', 'sentiment': "{'neg': 0.186, 'neu': 0.574, 'pos': 0.24, 'compound': 0.6815}", 'sentiment_score': 0.6815, 'rating_match': 'Incorrect'}),
#  Document(page_content='This bra is so well made and fits beautifully.', metadata={'product_id': 1154, 'age': 44, 'review_title': 'Worth every penny!', 'ratings': 5, 'product_type': 'Intimate', 'sentiment': "{'neg': 0.0, 'neu': 0.341, 'pos': 0.659, 'compound': 0.7003}", 'sentiment_score': 0.7003, 'rating_match': 'Correct'}),
#  Document(page_content='Snapped this sweet puppy up at my local retailer-in the sale room!!!!! it is beyond fabulous and the coral color is divine!!!! brightens up the drearriest of days-i did size down. i am short and the small sleeves were way too long on my 5ft3in frame. it runs a bit large but if you were to wear a heavier something under it i could see getting your "normal" size. the quality is great and the style is just lovely. great jacket-love love love', metadata={'product_id': 936, 'age': 47, 'review_title': 'Lovely', 'ratings': 5, 'product_type': 'Tops', 'sentiment': "{'neg': 0.0, 'neu': 0.501, 'pos': 0.499, 'compound': 0.9871}", 'sentiment_score': 0.9871, 'rating_match': 'Correct'}),
#  Document(page_content='Love this coat - great fall piece! i bought the green color and it looks as shown in the picture. great retailer purchase!', metadata={'product_id': 936, 'age': 42, 'review_title': 'Beautiful coat', 'ratings': 5, 'product_type': 'Tops', 'sentiment': "{'neg': 0.0, 'neu': 0.47, 'pos': 0.53, 'compound': 0.9246}", 'sentiment_score': 0.9246, 'rating_match': 'Correct'}),
#  Document(page_content="I bought it to mainly wear as a coat but i think it'd be great with some leggings and boots as well. if you want a more structured look go a size smaller. i plan on wearing this more as outer wear so i went with large. the coral is beautiful", metadata={'product_id': 936, 'age': 31, 'review_title': 'Love this!', 'ratings': 5, 'product_type': 'Tops', 'sentiment': "{'neg': 0.0, 'neu': 0.637, 'pos': 0.363, 'compound': 0.886}", 'sentiment_score': 0.886, 'rating_match': 'Correct'}),
#  Document(page_content='This tunic is very nice. flattering, good design, worn in winter and spring, and fits well. i have a curvy figure, and this fits well. i wish it came in more colors.it does show flaws slightly but fits well and is stretchy.', metadata={'product_id': 868, 'age': 26, 'review_title': 'Cute tunic', 'ratings': 4, 'product_type': 'Tops', 'sentiment': "{'neg': 0.064, 'neu': 0.439, 'pos': 0.497, 'compound': 0.9153}", 'sentiment_score': 0.9153, 'rating_match': 'Correct'}),
#  Document(page_content="The top i received was large, really long in length, pockets in the front along the seam, and lots of volume in the back without any princess seams to give it shape. the id #'s matched, but that's about it. returned!", metadata={'product_id': 854, 'age': 59, 'review_title': 'Misleading picture!', 'ratings': 1, 'product_type': 'Tops', 'sentiment': "{'neg': 0.0, 'neu': 0.921, 'pos': 0.079, 'compound': 0.2023}", 'sentiment_score': 0.2023, 'rating_match': 'Incorrect'}),
#  Document(page_content="At first, i thought this sweater might be too boxy, but fastened at the waist, it's very flattering and the collar is face-framing, and the coral in particular (really more of a mango sorbet shade) is unexpected but cheery for winter.\n\nbut the big selling point is the warmth and the giant pockets. brought a new puppy home just after christmas, and this sweater is perfect for layering for late- night trips out with an easy place to stash my phone and treats. bought it in coral and pink.", metadata={'product_id': 936, 'age': 33, 'review_title': 'Cozy, flattering, and practical', 'ratings': 5, 'product_type': 'Tops', 'sentiment': "{'neg': 0.0, 'neu': 0.716, 'pos': 0.284, 'compound': 0.9382}", 'sentiment_score': 0.9382, 'rating_match': 'Correct'}),
#  Document(page_content="I love this sweater! pros: great shape (it's supposed to be a little oversized looking), great color (i have the ivory and it's beautiful), and fits well (the sweater looks boxy until you put it on and it flows in all the right places). the sweater is not soft. that is my only con. it looks so soft in the photos, but the sweater i received is not at all soft and cozy. it is warm. it will be great for the winter - great pair with leggings, skirts or just jeans.", metadata={'product_id': 949, 'age': 47, 'review_title': 'Great sweater!', 'ratings': 4, 'product_type': 'Tops', 'sentiment': "{'neg': 0.0, 'neu': 0.529, 'pos': 0.471, 'compound': 0.9826}", 'sentiment_score': 0.9826, 'rating_match': 'Correct'}),
#  Document(page_content='I love this dress. will be wearing it for the first time tomorrow. it fits well. the neck line is a bit low on me. i think it would look best on someone with more of a chest than i have. i will be wearing a winter white infinity scarf with it (as shown on model). i am 5\' 6.5" and 120 lbs and the small is just right.', metadata={'product_id': 1094, 'age': 46, 'review_title': 'Beautiful', 'ratings': 5, 'product_type': 'Dresses', 'sentiment': "{'neg': 0.054, 'neu': 0.674, 'pos': 0.272, 'compound': 0.8555}", 'sentiment_score': 0.8555, 'rating_match': 'Correct'}),
#  Document(page_content="Love this sweater jacket! super comfortable and warm. i am 5'2 and i got a xs petite. it fit perfectly both in length and in the sleeve. the green color is super rich and is perfect for the season. it's easy to wear it up and wear it down. i appreciate that it's not super bulky, which was what i was afraid of. my favorite jacket of the season so far.", metadata={'product_id': 936, 'age': 24, 'review_title': 'Best sweater jacket!', 'ratings': 5, 'product_type': 'Tops', 'sentiment': "{'neg': 0.0, 'neu': 0.292, 'pos': 0.708, 'compound': 0.9921}", 'sentiment_score': 0.9921, 'rating_match': 'Correct'}),
#  Document(page_content='I am 5\'6", 130 lbs with an athletic body type and i ordered a size small. these were really baggy in the thigh/quadricep area and made my thighs look bulky. the fabric quality is very nice and i like the idea of them for curvier body types. my son commented that they looked like pajama pants and i agreed.', metadata={'product_id': 1047, 'age': 34, 'review_title': 'Not for every body type', 'ratings': 2, 'product_type': 'Bottoms', 'sentiment': "{'neg': 0.0, 'neu': 0.739, 'pos': 0.261, 'compound': 0.836}", 'sentiment_score': 0.836, 'rating_match': 'Incorrect'}),
#  Document(page_content='This is a beautiful dress but if you have any hips at all you may find it difficult to find the right size. i usually wear a 0-2 p and found that that the op was too snug on the bottom while the 2p was too loose on top. ( for reference 32-26-35). so if you are perfectly proportioned it could work for you.\r\nalso, note that this is a pencil dress....very slim fitting.....probably best suited for a cocktail party.', metadata={'product_id': 1083, 'age': 53, 'review_title': 'Best for staright figures', 'ratings': 4, 'product_type': 'Dresses', 'sentiment': "{'neg': 0.097, 'neu': 0.565, 'pos': 0.339, 'compound': 0.9186}", 'sentiment_score': 0.9186, 'rating_match': 'Correct'}),
#  Document(page_content='Purchased this sweater in the blue color which is a gray/blue. it runs large as the xs is still quite roomy on me in the body. although the arms are more snug. great quality.', metadata={'product_id': 949, 'age': 38, 'review_title': 'Cute sweater!', 'ratings': 5, 'product_type': 'Tops', 'sentiment': "{'neg': 0.0, 'neu': 0.796, 'pos': 0.204, 'compound': 0.6249}", 'sentiment_score': 0.6249, 'rating_match': 'Correct'}),
#  Document(page_content="I bought this as a birthday gift for my daughter, and i am so glad i did. the colors are beautiful, and the material is so soft. i'm sure she's going to love it!", metadata={'product_id': 949, 'age': 58, 'review_title': 'So happy i ordered this!', 'ratings': 5, 'product_type': 'Tops', 'sentiment': "{'neg': 0.0, 'neu': 0.356, 'pos': 0.644, 'compound': 0.946}", 'sentiment_score': 0.946, 'rating_match': 'Correct'}),
#  Document(page_content="So when i saw a sweater with a big llama face on the front of it, i knew it must be mine. i ordered it and eagerly awaited its arrival. while the llama print and color of the sweater are ah-mazing, the fit of the sweater leaves something to be desired. i'm a 36 dd and mostly a size l, so that's what i ordered. it wasn't snug, but it didn't have the cut to pull off the oversized drapey look, so the areas where it was loose looked...strange. the sleeves were really long too, but i could have rolle", metadata={'product_id': 909, 'age': 33, 'review_title': 'Wanted to love it, but just kinda like it', 'ratings': 3, 'product_type': 'Tops', 'sentiment': "{'neg': 0.096, 'neu': 0.766, 'pos': 0.138, 'compound': 0.4935}", 'sentiment_score': 0.4935, 'rating_match': 'Incorrect'}),
#  Document(page_content='I fell in love with this top (sweater) before it could even be ordered - was on model for pants that were available to order. in any case, i later ordered the blue motif online and the colors are even more beautiful in person. the blue also contains fibers of wine - so very pretty. the gray is a soft shade. the quality is lovely too. the only cons are that the seater is rather heavy, but should be great for colder winter months and the zipper on the back is quite conspicuous. however, that said,', metadata={'product_id': 949, 'age': 67, 'review_title': 'Lovely top', 'ratings': 5, 'product_type': 'Tops', 'sentiment': "{'neg': 0.0, 'neu': 0.656, 'pos': 0.344, 'compound': 0.9682}", 'sentiment_score': 0.9682, 'rating_match': 'Correct'}),
#  Document(page_content="Love the feminine styling of a classic tunic tee! i'll wear it with black leggings this fall. super cute to wear casually or dress up a bit with some jewelry and/or a scarf.", metadata={'product_id': 873, 'age': 32, 'review_title': 'Comfy & cute', 'ratings': 5, 'product_type': 'Tops', 'sentiment': "{'neg': 0.092, 'neu': 0.49, 'pos': 0.418, 'compound': 0.875}", 'sentiment_score': 0.875, 'rating_match': 'Correct'}),
#  Document(page_content='This top is full of amazing details. the photos really don\'t do it justice. it is very flowy and does run large but is so pretty and soft and in beautiful shades of blue. i bought a small and it is fairly long in back on my 5\'5" frame but because of the detailing...it just works.', metadata={'product_id': 873, 'age': 59, 'review_title': 'unknown', 'ratings': 5, 'product_type': 'Tops', 'sentiment': "{'neg': 0.085, 'neu': 0.559, 'pos': 0.355, 'compound': 0.864}", 'sentiment_score': 0.864, 'rating_match': 'Correct'}),
#  Document(page_content='Unlike the first three reviews, i loved this sweater. the colors were beautiful and i paired it with green cords. i did not find the sweater to be itchy but very comfortable. fits trus to size.', metadata={'product_id': 909, 'age': 82, 'review_title': 'Love this sweater', 'ratings': 5, 'product_type': 'Tops', 'sentiment': "{'neg': 0.077, 'neu': 0.515, 'pos': 0.408, 'compound': 0.875}", 'sentiment_score': 0.875, 'rating_match': 'Correct'}),
#  Document(page_content="Great fit even for busty women. ordered an 8 because i usually need the room in the chest area on dresses.(36d-dd) fit nicely without being tight. might have been able to size down but i didn't want to risk being too tight. flattering especially on curves. nice for contemporary office or special occasion. if you like his designs, you won't be disappointed!", metadata={'product_id': 1083, 'age': 46, 'review_title': 'Classically byron lars', 'ratings': 5, 'product_type': 'Dresses', 'sentiment': "{'neg': 0.023, 'neu': 0.46, 'pos': 0.517, 'compound': 0.9742}", 'sentiment_score': 0.9742, 'rating_match': 'Correct'}),
#  Document(page_content="Love this top, purchased it in the coral color now i'm definitely wanting it in the blue since it is such a great blouse for transitioning into fall. the weight of the top it good since i live in south texas so definitely needing lightweight long sleeves for our weather. i'm sure when the time comes adding a long cardigan or blazer over it as needed for the cooler weather it will look great. fit true to size.", metadata={'product_id': 873, 'age': 34, 'review_title': 'Great blouse', 'ratings': 5, 'product_type': 'Tops', 'sentiment': "{'neg': 0.0, 'neu': 0.501, 'pos': 0.499, 'compound': 0.9833}", 'sentiment_score': 0.9833, 'rating_match': 'Correct'}),
#  Document(page_content="Absolutely love this suit. the bottoms are very comfortable and covers everything id like it to. it does not ride up at all, which almost never happens with swim suits. i'm going to order this in a different color next season. i paired the bottoms with the peplum top and received many compliments.", metadata={'product_id': 1172, 'age': 25, 'review_title': 'unknown', 'ratings': 5, 'product_type': 'Intimate', 'sentiment': "{'neg': 0.0, 'neu': 0.619, 'pos': 0.381, 'compound': 0.9299}", 'sentiment_score': 0.9299, 'rating_match': 'Correct'}),
#  Document(page_content='I just love this dress.  took me ordering a number of sizes- petite and regular to find the best fit.  i might still have the top altered.  i received a lot of compliements.  work it with some black leather wedges for daytime/work.', metadata={'product_id': 1083, 'age': 35, 'review_title': 'Awesome dress', 'ratings': 5, 'product_type': 'Dresses', 'sentiment': "{'neg': 0.0, 'neu': 0.562, 'pos': 0.438, 'compound': 0.9186}", 'sentiment_score': 0.9186, 'rating_match': 'Correct'}),
#  Document(page_content='I got the purple color and absolutely love it. i am 5\'2" but decided against the petite size and i wanted it to be a bit longer. i also went with the xxs as the xs was a bit too loose on the arm. it was definitely a splurge to buy the sweater but it looked so lovely!', metadata={'product_id': 949, 'age': 42, 'review_title': 'Beautiful!', 'ratings': 5, 'product_type': 'Tops', 'sentiment': "{'neg': 0.067, 'neu': 0.612, 'pos': 0.321, 'compound': 0.8655}", 'sentiment_score': 0.8655, 'rating_match': 'Correct'}),
#  Document(page_content="Love the color! very soft. unique look. can't wait to wear it this fall", metadata={'product_id': 949, 'age': 35, 'review_title': 'Cute sweater!', 'ratings': 5, 'product_type': 'Tops', 'sentiment': "{'neg': 0.0, 'neu': 0.656, 'pos': 0.344, 'compound': 0.6369}", 'sentiment_score': 0.6369, 'rating_match': 'Correct'}),
#  Document(page_content="I got the rooster version and the colors are simply gorgeous.  i'm not so much into wearing a farm animal image, but the colors are just too striking to pass this up. the sweater is tts, but with a slightly baggy fit. i did not find it scratchy.", metadata={'product_id': 909, 'age': 41, 'review_title': 'Nice', 'ratings': 4, 'product_type': 'Tops', 'sentiment': "{'neg': 0.0, 'neu': 0.763, 'pos': 0.237, 'compound': 0.7369}", 'sentiment_score': 0.7369, 'rating_match': 'Correct'}),
#  ...]
